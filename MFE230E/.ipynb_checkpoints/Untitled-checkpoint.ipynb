# %%
import statsmodels.api as sm
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
port = pd.read_csv('25_Portfolios_ME_Prior_12_2.CSV', skiprows=11, nrows=1167)
mom = pd.read_csv('F-F_Momentum_Factor.CSV',skiprows=13, nrows=1167)
fact = pd.read_csv('F-F_Research_Data_5_Factors_2x3.csv', skiprows=3, nrows=729)

port.drop(port.tail(1).index, inplace=True)
mom.drop(mom.tail(1).index, inplace=True)
fact.drop(fact.tail(1).index, inplace=True)


port['Unnamed: 0'] = port['Unnamed: 0'].astype(int)
mom['Unnamed: 0'] = mom['Unnamed: 0'].astype(int)
fact['Unnamed: 0'] = fact['Unnamed: 0'].astype(int)

port.set_index('Unnamed: 0' , inplace=True)
mom.set_index('Unnamed: 0' , inplace=True)
fact.set_index('Unnamed: 0' , inplace=True)

# %%
data = port.join(fact, rsuffix='r').join(mom, rsuffix='r').dropna()

# %%
portfolios = port.columns

# %%
portfolios
# Out:
# Index(['SMALL LoPRIOR', 'ME1 PRIOR2', 'ME1 PRIOR3', 'ME1 PRIOR4',
#        'SMALL HiPRIOR', 'ME2 PRIOR1', 'ME2 PRIOR2', 'ME2 PRIOR3', 'ME2 PRIOR4',
#        'ME2 PRIOR5', 'ME3 PRIOR1', 'ME3 PRIOR2', 'ME3 PRIOR3', 'ME3 PRIOR4',
#        'ME3 PRIOR5', 'ME4 PRIOR1', 'ME4 PRIOR2', 'ME4 PRIOR3', 'ME4 PRIOR4',
#        'ME4 PRIOR5', 'BIG LoPRIOR', 'ME5 PRIOR2', 'ME5 PRIOR3', 'ME5 PRIOR4',
#        'BIG HiPRIOR'],
#       dtype='object')

# %%
res_all = []
for p in portfolios:
    res = sm.OLS(data[p] - data['RF'], sm.add_constant(data['Mkt-RF'])).fit(cov_type='HC0')
    res_all.append(res)
    print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.586
# Model:                            OLS   Adj. R-squared:                  0.585
# Method:                 Least Squares   F-statistic:                     608.4
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):           4.82e-98
# Time:                        21:25:44   Log-Likelihood:                -2250.6
# No. Observations:                 728   AIC:                             4505.
# Df Residuals:                     726   BIC:                             4514.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7194      0.186     -3.860      0.000      -1.085      -0.354
# Mkt-RF         1.4103      0.057     24.666      0.000       1.298       1.522
# ==============================================================================
# Omnibus:                      316.358   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3109.022
# Skew:                           1.685   Prob(JB):                         0.00
# Kurtosis:                      12.546   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.640
# Model:                            OLS   Adj. R-squared:                  0.639
# Method:                 Least Squares   F-statistic:                     646.6
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.67e-102
# Time:                        21:25:44   Log-Likelihood:                -1959.6
# No. Observations:                 728   AIC:                             3923.
# Df Residuals:                     726   BIC:                             3932.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0693      0.129      0.538      0.590      -0.183       0.322
# Mkt-RF         1.0594      0.042     25.429      0.000       0.978       1.141
# ==============================================================================
# Omnibus:                      116.946   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              449.608
# Skew:                           0.703   Prob(JB):                     2.34e-98
# Kurtosis:                       6.584   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.658
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     684.5
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          8.39e-107
# Time:                        21:25:44   Log-Likelihood:                -1877.5
# No. Observations:                 728   AIC:                             3759.
# Df Residuals:                     726   BIC:                             3768.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3119      0.118      2.635      0.008       0.080       0.544
# Mkt-RF         0.9862      0.038     26.163      0.000       0.912       1.060
# ==============================================================================
# Omnibus:                       64.573   Durbin-Watson:                   1.847
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              155.637
# Skew:                           0.487   Prob(JB):                     1.60e-34
# Kurtosis:                       5.045   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.652
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     706.4
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          3.13e-109
# Time:                        21:25:44   Log-Likelihood:                -1892.6
# No. Observations:                 728   AIC:                             3789.
# Df Residuals:                     726   BIC:                             3798.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4545      0.123      3.703      0.000       0.214       0.695
# Mkt-RF         0.9933      0.037     26.578      0.000       0.920       1.067
# ==============================================================================
# Omnibus:                       34.446   Durbin-Watson:                   1.773
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.806
# Skew:                           0.316   Prob(JB):                     8.46e-15
# Kurtosis:                       4.318   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.631
# Model:                            OLS   Adj. R-squared:                  0.631
# Method:                 Least Squares   F-statistic:                     864.9
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          8.38e-126
# Time:                        21:25:44   Log-Likelihood:                -2061.0
# No. Observations:                 728   AIC:                             4126.
# Df Residuals:                     726   BIC:                             4135.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6062      0.155      3.922      0.000       0.303       0.909
# Mkt-RF         1.1959      0.041     29.410      0.000       1.116       1.276
# ==============================================================================
# Omnibus:                      146.470   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              598.045
# Skew:                           0.875   Prob(JB):                    1.37e-130
# Kurtosis:                       7.081   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.685
# Model:                            OLS   Adj. R-squared:                  0.684
# Method:                 Least Squares   F-statistic:                     828.5
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          3.77e-122
# Time:                        21:25:44   Log-Likelihood:                -2126.1
# No. Observations:                 728   AIC:                             4256.
# Df Residuals:                     726   BIC:                             4265.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6350      0.157     -4.045      0.000      -0.943      -0.327
# Mkt-RF         1.4732      0.051     28.784      0.000       1.373       1.573
# ==============================================================================
# Omnibus:                      346.816   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5444.078
# Skew:                           1.733   Prob(JB):                         0.00
# Kurtosis:                      15.941   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.727
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     968.8
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          8.67e-136
# Time:                        21:25:44   Log-Likelihood:                -1861.6
# No. Observations:                 728   AIC:                             3727.
# Df Residuals:                     726   BIC:                             3736.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0465      0.113      0.411      0.681      -0.175       0.268
# Mkt-RF         1.1354      0.036     31.126      0.000       1.064       1.207
# ==============================================================================
# Omnibus:                      155.058   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              857.344
# Skew:                           0.834   Prob(JB):                    6.76e-187
# Kurtosis:                       8.048   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     1051.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.74e-143
# Time:                        21:25:44   Log-Likelihood:                -1743.9
# No. Observations:                 728   AIC:                             3492.
# Df Residuals:                     726   BIC:                             3501.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2448      0.100      2.459      0.014       0.050       0.440
# Mkt-RF         1.0378      0.032     32.424      0.000       0.975       1.101
# ==============================================================================
# Omnibus:                       28.757   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.281
# Skew:                           0.250   Prob(JB):                     9.91e-13
# Kurtosis:                       4.254   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     1079.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.03e-145
# Time:                        21:25:44   Log-Likelihood:                -1763.0
# No. Observations:                 728   AIC:                             3530.
# Df Residuals:                     726   BIC:                             3539.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3931      0.102      3.843      0.000       0.193       0.594
# Mkt-RF         1.0592      0.032     32.846      0.000       0.996       1.122
# ==============================================================================
# Omnibus:                       15.550   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.047
# Skew:                           0.055   Prob(JB):                     4.93e-07
# Kurtosis:                       3.972   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.714
# Model:                            OLS   Adj. R-squared:                  0.714
# Method:                 Least Squares   F-statistic:                     1400.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.46e-171
# Time:                        21:25:44   Log-Likelihood:                -1970.9
# No. Observations:                 728   AIC:                             3946.
# Df Residuals:                     726   BIC:                             3955.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4929      0.135      3.652      0.000       0.228       0.757
# Mkt-RF         1.2763      0.034     37.419      0.000       1.209       1.343
# ==============================================================================
# Omnibus:                      202.226   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1486.045
# Skew:                           1.041   Prob(JB):                         0.00
# Kurtosis:                       9.683   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     790.4
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          3.12e-118
# Time:                        21:25:44   Log-Likelihood:                -2091.1
# No. Observations:                 728   AIC:                             4186.
# Df Residuals:                     726   BIC:                             4195.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4958      0.154     -3.218      0.001      -0.798      -0.194
# Mkt-RF         1.3975      0.050     28.114      0.000       1.300       1.495
# ==============================================================================
# Omnibus:                      194.387   Durbin-Watson:                   1.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1051.764
# Skew:                           1.089   Prob(JB):                    4.10e-229
# Kurtosis:                       8.471   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     1292.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.36e-163
# Time:                        21:25:44   Log-Likelihood:                -1752.4
# No. Observations:                 728   AIC:                             3509.
# Df Residuals:                     726   BIC:                             3518.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0107      0.098     -0.109      0.913      -0.203       0.182
# Mkt-RF         1.1256      0.031     35.949      0.000       1.064       1.187
# ==============================================================================
# Omnibus:                       69.623   Durbin-Watson:                   1.886
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              276.833
# Skew:                           0.349   Prob(JB):                     7.70e-61
# Kurtosis:                       5.939   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     1306.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.90e-164
# Time:                        21:25:44   Log-Likelihood:                -1643.1
# No. Observations:                 728   AIC:                             3290.
# Df Residuals:                     726   BIC:                             3299.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1470      0.086      1.700      0.089      -0.022       0.316
# Mkt-RF         1.0270      0.028     36.144      0.000       0.971       1.083
# ==============================================================================
# Omnibus:                       66.988   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              290.064
# Skew:                           0.288   Prob(JB):                     1.03e-63
# Kurtosis:                       6.038   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.807
# Method:                 Least Squares   F-statistic:                     1332.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.08e-166
# Time:                        21:25:44   Log-Likelihood:                -1617.3
# No. Observations:                 728   AIC:                             3239.
# Df Residuals:                     726   BIC:                             3248.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1778      0.085      2.081      0.037       0.010       0.345
# Mkt-RF         1.0163      0.028     36.494      0.000       0.962       1.071
# ==============================================================================
# Omnibus:                       25.997   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.862
# Skew:                          -0.157   Prob(JB):                     4.49e-13
# Kurtosis:                       4.332   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.752
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     1645.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          9.24e-189
# Time:                        21:25:44   Log-Likelihood:                -1862.8
# No. Observations:                 728   AIC:                             3730.
# Df Residuals:                     726   BIC:                             3739.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4613      0.117      3.935      0.000       0.232       0.691
# Mkt-RF         1.2114      0.030     40.559      0.000       1.153       1.270
# ==============================================================================
# Omnibus:                       97.079   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              416.511
# Skew:                           0.533   Prob(JB):                     3.60e-91
# Kurtosis:                       6.549   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     535.9
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):           3.17e-89
# Time:                        21:25:44   Log-Likelihood:                -2106.0
# No. Observations:                 728   AIC:                             4216.
# Df Residuals:                     726   BIC:                             4225.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5286      0.162     -3.257      0.001      -0.847      -0.211
# Mkt-RF         1.3794      0.060     23.150      0.000       1.263       1.496
# ==============================================================================
# Omnibus:                      235.612   Durbin-Watson:                   1.950
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2452.086
# Skew:                           1.140   Prob(JB):                         0.00
# Kurtosis:                      11.697   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.801
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     1555.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.11e-182
# Time:                        21:25:44   Log-Likelihood:                -1705.7
# No. Observations:                 728   AIC:                             3415.
# Df Residuals:                     726   BIC:                             3425.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0033      0.093      0.035      0.972      -0.179       0.186
# Mkt-RF         1.1256      0.029     39.439      0.000       1.070       1.182
# ==============================================================================
# Omnibus:                      100.401   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              787.073
# Skew:                           0.319   Prob(JB):                    1.23e-171
# Kurtosis:                       8.054   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     1917.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          6.79e-206
# Time:                        21:25:44   Log-Likelihood:                -1511.5
# No. Observations:                 728   AIC:                             3027.
# Df Residuals:                     726   BIC:                             3036.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1135      0.072      1.567      0.117      -0.028       0.256
# Mkt-RF         1.0106      0.023     43.785      0.000       0.965       1.056
# ==============================================================================
# Omnibus:                       83.246   Durbin-Watson:                   1.793
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              609.221
# Skew:                           0.157   Prob(JB):                    5.12e-133
# Kurtosis:                       7.471   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     2646.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.76e-244
# Time:                        21:25:44   Log-Likelihood:                -1443.8
# No. Observations:                 728   AIC:                             2892.
# Df Residuals:                     726   BIC:                             2901.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2163      0.067      3.210      0.001       0.084       0.348
# Mkt-RF         0.9951      0.019     51.435      0.000       0.957       1.033
# ==============================================================================
# Omnibus:                       42.906   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              136.243
# Skew:                           0.180   Prob(JB):                     2.60e-30
# Kurtosis:                       5.089   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.763
# Method:                 Least Squares   F-statistic:                     1754.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          7.20e-196
# Time:                        21:25:44   Log-Likelihood:                -1791.6
# No. Observations:                 728   AIC:                             3587.
# Df Residuals:                     726   BIC:                             3596.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3759      0.105      3.570      0.000       0.170       0.582
# Mkt-RF         1.1341      0.027     41.885      0.000       1.081       1.187
# ==============================================================================
# Omnibus:                       98.129   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              876.155
# Skew:                           0.217   Prob(JB):                    5.56e-191
# Kurtosis:                       8.357   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     563.3
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):           1.28e-92
# Time:                        21:25:44   Log-Likelihood:                -2071.3
# No. Observations:                 728   AIC:                             4147.
# Df Residuals:                     726   BIC:                             4156.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4529      0.156     -2.905      0.004      -0.759      -0.147
# Mkt-RF         1.2730      0.054     23.734      0.000       1.168       1.378
# ==============================================================================
# Omnibus:                      119.944   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              696.993
# Skew:                           0.589   Prob(JB):                    4.46e-152
# Kurtosis:                       7.647   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     862.8
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.38e-125
# Time:                        21:25:44   Log-Likelihood:                -1712.1
# No. Observations:                 728   AIC:                             3428.
# Df Residuals:                     726   BIC:                             3437.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0098      0.096     -0.103      0.918      -0.197       0.177
# Mkt-RF         0.9561      0.033     29.373      0.000       0.892       1.020
# ==============================================================================
# Omnibus:                       89.660   Durbin-Watson:                   1.756
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              746.594
# Skew:                           0.146   Prob(JB):                    7.57e-163
# Kurtosis:                       7.952   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     2932.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          3.80e-257
# Time:                        21:25:44   Log-Likelihood:                -1410.5
# No. Observations:                 728   AIC:                             2825.
# Df Residuals:                     726   BIC:                             2834.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0403      0.061     -0.660      0.509      -0.160       0.079
# Mkt-RF         0.9106      0.017     54.148      0.000       0.878       0.944
# ==============================================================================
# Omnibus:                      131.653   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1446.522
# Skew:                          -0.436   Prob(JB):                         0.00
# Kurtosis:                       9.850   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     2322.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.30e-228
# Time:                        21:25:44   Log-Likelihood:                -1427.8
# No. Observations:                 728   AIC:                             2860.
# Df Residuals:                     726   BIC:                             2869.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0901      0.062      1.444      0.149      -0.032       0.212
# Mkt-RF         0.8859      0.018     48.185      0.000       0.850       0.922
# ==============================================================================
# Omnibus:                       60.037   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              310.187
# Skew:                           0.028   Prob(JB):                     4.40e-68
# Kurtosis:                       6.197   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.757
# Method:                 Least Squares   F-statistic:                     1431.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          8.20e-174
# Time:                        21:25:44   Log-Likelihood:                -1714.2
# No. Observations:                 728   AIC:                             3432.
# Df Residuals:                     726   BIC:                             3442.
# Df Model:                           1
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2468      0.095      2.604      0.009       0.061       0.433
# Mkt-RF         1.0023      0.026     37.825      0.000       0.950       1.054
# ==============================================================================
# Omnibus:                       40.688   Durbin-Watson:                   1.920
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              128.236
# Skew:                          -0.152   Prob(JB):                     1.43e-28
# Kurtosis:                       5.033   Cond. No.                         4.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)

# %% [markdown]
# Observing the results of the regressions we see that the P values for the betas are universally very small and so are the standard deviations. Thus I belive the Betas are estimated accuratly.

# %% [markdown]
# b) For most protfolios the alphas have a low p value, but not for all. We also see that the range for the alphas is significantly larger than that of the betas. Hence, I think that the alphas are much less significant than the betas, possibly not economically significant at all.

# %% [markdown]
# c) not sure

# %%
alphas = [i.params[0] for i in res_all]
means = [data[i].mean() for i in portfolios]

fig, ax = plt.subplots()
ax.scatter(betas, means)

ax.set_xlabel('CAPM Fit Alpha')
ax.set_ylabel('Average Portfolio Return')
# Out:
# /tmp/ipykernel_111978/2810298609.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alphas = [i.params[0] for i in res_all]
# Text(0, 0.5, 'Average Portfolio Return')

# %%
for p, i in zip(portfolios, res_all):
    print(p,':', i.tvalues[0])
# Out:
# SMALL LoPRIOR : -3.8603212614320923
# ME1 PRIOR2 : 0.5382033628727428
# ME1 PRIOR3 : 2.634806552268032
# ME1 PRIOR4 : 3.70324440011955
# SMALL HiPRIOR : 3.922141544411007
# ME2 PRIOR1 : -4.045179580241544
# ME2 PRIOR2 : 0.4111281656551372
# ME2 PRIOR3 : 2.4589851688326445
# ME2 PRIOR4 : 3.842768131355204
# ME2 PRIOR5 : 3.651974960266981
# ME3 PRIOR1 : -3.2177435546665802
# ME3 PRIOR2 : -0.1090842385822105
# ME3 PRIOR3 : 1.7000428962007548
# ME3 PRIOR4 : 2.080768563641185
# ME3 PRIOR5 : 3.935087634534737
# ME4 PRIOR1 : -3.2574024951604375
# ME4 PRIOR2 : 0.03513560732609473
# ME4 PRIOR3 : 1.5669150405227732
# ME4 PRIOR4 : 3.209731539525625
# ME4 PRIOR5 : 3.5701678094829563
# BIG LoPRIOR : -2.904735440517503
# ME5 PRIOR2 : -0.10282590243373377
# ME5 PRIOR3 : -0.6596352191944346
# ME5 PRIOR4 : 1.44414576965186
# BIG HiPRIOR : 2.603801105131941
# /tmp/ipykernel_111978/1526723268.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(p,':', i.tvalues[0])

# %% [markdown]
# We see here that the alpha is not always significant based on the t-test.

# %% [markdown]
# e) Compute the GRS test for the joint null H0 : αi = 0 ∀i

# %%
errors = []
for r in res_all:
    errors.append(r.resid)

cov_matrix = np.cov(errors)

market_sr = data['Mkt-RF'].mean()/data['Mkt-RF'].std()

GRS = np.array(alphas) @ np.linalg.inv(cov_matrix) @ (np.array(alphas)/(1+market_sr**2)*len(data))
print("GRS:", GRS)

from scipy.stats import chi2
df = 25
print("Chi-squared test: p-val=", 1-chi2.cdf(GRS, 25, loc=0, scale=1))
# Out:
# GRS: 105.21414864114391
# Chi-squared test: p-val= 8.18789480661053e-12

# %% [markdown]
# f) Plot the theoretical Capital Market Line and the mean-variance frontier spanned by the 25 portfolios.
# How does this figure relate to the regression pricing errors?

# %%
means = [data[i].mean() for i in portfolios]
variances = [data[i].std() for i in portfolios]


fig, ax = plt.subplots()
ax.scatter(variances, means)


x = np.linspace(0, 10, 500)
ax.plot(x, [ data['RF'].mean() + (data['Mkt-RF'].mean()/data['Mkt-RF'].std())*i for i in x], linestyle='-', color='red', label='CML')


ax.set_xlabel('Variance')
ax.set_ylabel('Mean Return')

fig.show()
# Out:
# /tmp/ipykernel_111978/2672149714.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Out:
#   Cell In[163], line 3
#     ef = EfficientFrontier(np.mean(data(train_data), np.cov(np.array(train_data).T), weight_bounds=(None, None))
#                           ^
# SyntaxError: '(' was never closed

# %%
(data['RF'].mean() + (data['Mkt-RF'].mean()/data['Mkt-RF'].std()) )
# Out:
# 0.49077533848847443

# %% [markdown]
# g) Over

# %% [markdown]
# # 5

# %%
res_all = []
for p in portfolios:
    res = sm.OLS(data[p] - data['RF'], sm.add_constant(data[['Mkt-RF', 'SMB', 'HML', 'Mom   ' ]])).fit(cov_type='HC0')
    res_all.append(res)
    print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                     1229.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.15e-320
# Time:                        22:56:43   Log-Likelihood:                -1706.5
# No. Observations:                 728   AIC:                             3423.
# Df Residuals:                     723   BIC:                             3446.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3551      0.115     -3.081      0.002      -0.581      -0.129
# Mkt-RF         1.0593      0.028     38.286      0.000       1.005       1.114
# SMB            1.2630      0.046     27.201      0.000       1.172       1.354
# HML           -0.0197      0.053     -0.373      0.709      -0.123       0.084
# Mom           -0.6795      0.056    -12.072      0.000      -0.790      -0.569
# ==============================================================================
# Omnibus:                      214.840   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1962.700
# Skew:                           1.051   Prob(JB):                         0.00
# Kurtosis:                      10.764   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                     1285.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1334.3
# No. Observations:                 728   AIC:                             2679.
# Df Residuals:                     723   BIC:                             2702.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0543      0.058      0.932      0.351      -0.060       0.168
# Mkt-RF         0.8706      0.016     53.791      0.000       0.839       0.902
# SMB            0.9763      0.037     26.226      0.000       0.903       1.049
# HML            0.2590      0.028      9.091      0.000       0.203       0.315
# Mom           -0.2448      0.023    -10.862      0.000      -0.289      -0.201
# ==============================================================================
# Omnibus:                       53.165   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              241.057
# Skew:                          -0.010   Prob(JB):                     4.52e-53
# Kurtosis:                       5.819   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     1328.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1319.3
# No. Observations:                 728   AIC:                             2649.
# Df Residuals:                     723   BIC:                             2672.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1618      0.054      2.975      0.003       0.055       0.268
# Mkt-RF         0.8489      0.016     51.647      0.000       0.817       0.881
# SMB            0.8891      0.041     21.877      0.000       0.809       0.969
# HML            0.3046      0.026     11.699      0.000       0.254       0.356
# Mom           -0.0646      0.023     -2.772      0.006      -0.110      -0.019
# ==============================================================================
# Omnibus:                       94.529   Durbin-Watson:                   1.981
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              545.188
# Skew:                          -0.405   Prob(JB):                    4.11e-119
# Kurtosis:                       7.161   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.917
# Model:                            OLS   Adj. R-squared:                  0.917
# Method:                 Least Squares   F-statistic:                     1237.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.40e-321
# Time:                        22:56:43   Log-Likelihood:                -1370.0
# No. Observations:                 728   AIC:                             2750.
# Df Residuals:                     723   BIC:                             2773.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2040      0.066      3.087      0.002       0.074       0.334
# Mkt-RF         0.8696      0.018     47.472      0.000       0.834       0.905
# SMB            0.9251      0.032     29.141      0.000       0.863       0.987
# HML            0.2756      0.032      8.502      0.000       0.212       0.339
# Mom            0.0879      0.028      3.121      0.002       0.033       0.143
# ==============================================================================
# Omnibus:                       76.491   Durbin-Watson:                   2.050
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              522.890
# Skew:                           0.092   Prob(JB):                    2.86e-114
# Kurtosis:                       7.148   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     1682.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1529.6
# No. Observations:                 728   AIC:                             3069.
# Df Residuals:                     723   BIC:                             3092.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2703      0.081      3.318      0.001       0.111       0.430
# Mkt-RF         1.0259      0.023     44.088      0.000       0.980       1.071
# SMB            1.1731      0.052     22.666      0.000       1.072       1.275
# HML            0.0380      0.041      0.934      0.350      -0.042       0.118
# Mom            0.2976      0.035      8.623      0.000       0.230       0.365
# ==============================================================================
# Omnibus:                      269.015   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2734.420
# Skew:                           1.361   Prob(JB):                         0.00
# Kurtosis:                      12.096   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.949
# Model:                            OLS   Adj. R-squared:                  0.949
# Method:                 Least Squares   F-statistic:                     1941.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1459.7
# No. Observations:                 728   AIC:                             2929.
# Df Residuals:                     723   BIC:                             2952.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2071      0.078     -2.654      0.008      -0.360      -0.054
# Mkt-RF         1.1675      0.017     66.830      0.000       1.133       1.202
# SMB            0.9707      0.030     32.081      0.000       0.911       1.030
# HML           -0.0580      0.028     -2.043      0.041      -0.114      -0.002
# Mom           -0.7103      0.043    -16.491      0.000      -0.795      -0.626
# ==============================================================================
# Omnibus:                      166.397   Durbin-Watson:                   1.656
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1600.822
# Skew:                           0.728   Prob(JB):                         0.00
# Kurtosis:                      10.117   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     1682.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1300.1
# No. Observations:                 728   AIC:                             2610.
# Df Residuals:                     723   BIC:                             2633.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1152      0.058      1.974      0.048       0.001       0.230
# Mkt-RF         0.9649      0.015     66.243      0.000       0.936       0.993
# SMB            0.7809      0.032     24.776      0.000       0.719       0.843
# HML            0.1875      0.024      7.800      0.000       0.140       0.235
# Mom           -0.3004      0.028    -10.827      0.000      -0.355      -0.246
# ==============================================================================
# Omnibus:                       69.379   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              331.436
# Skew:                           0.263   Prob(JB):                     1.07e-72
# Kurtosis:                       6.263   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.934
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     1758.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1268.2
# No. Observations:                 728   AIC:                             2546.
# Df Residuals:                     723   BIC:                             2569.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1182      0.055      2.151      0.031       0.010       0.226
# Mkt-RF         0.9331      0.016     59.330      0.000       0.902       0.964
# SMB            0.7011      0.030     23.230      0.000       0.642       0.760
# HML            0.2709      0.024     11.071      0.000       0.223       0.319
# Mom           -0.0550      0.019     -2.843      0.004      -0.093      -0.017
# ==============================================================================
# Omnibus:                       44.039   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              160.921
# Skew:                           0.084   Prob(JB):                     1.14e-35
# Kurtosis:                       5.297   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     2074.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1241.2
# No. Observations:                 728   AIC:                             2492.
# Df Residuals:                     723   BIC:                             2515.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1680      0.053      3.184      0.001       0.065       0.271
# Mkt-RF         0.9624      0.014     69.894      0.000       0.935       0.989
# SMB            0.7652      0.030     25.390      0.000       0.706       0.824
# HML            0.2548      0.023     11.020      0.000       0.209       0.300
# Mom            0.0844      0.020      4.286      0.000       0.046       0.123
# ==============================================================================
# Omnibus:                       50.701   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              218.977
# Skew:                           0.009   Prob(JB):                     2.82e-48
# Kurtosis:                       5.687   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     1425.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1398.6
# No. Observations:                 728   AIC:                             2807.
# Df Residuals:                     723   BIC:                             2830.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1443      0.065      2.230      0.026       0.017       0.271
# Mkt-RF         1.1444      0.020     56.908      0.000       1.105       1.184
# SMB            0.9929      0.037     26.864      0.000       0.921       1.065
# HML           -0.0123      0.033     -0.377      0.706      -0.076       0.051
# Mom            0.3660      0.024     15.572      0.000       0.320       0.412
# ==============================================================================
# Omnibus:                      183.565   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1332.082
# Skew:                           0.928   Prob(JB):                    5.52e-290
# Kurtosis:                       9.362   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.919
# Method:                 Least Squares   F-statistic:                     1035.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.97e-297
# Time:                        22:56:43   Log-Likelihood:                -1592.1
# No. Observations:                 728   AIC:                             3194.
# Df Residuals:                     723   BIC:                             3217.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0073      0.088     -0.083      0.934      -0.180       0.165
# Mkt-RF         1.1491      0.026     43.688      0.000       1.098       1.201
# SMB            0.6407      0.042     15.396      0.000       0.559       0.722
# HML           -0.0373      0.040     -0.921      0.357      -0.117       0.042
# Mom           -0.7620      0.026    -29.517      0.000      -0.813      -0.711
# ==============================================================================
# Omnibus:                       59.344   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              217.299
# Skew:                           0.291   Prob(JB):                     6.52e-48
# Kurtosis:                       5.613   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     1803.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:43   Log-Likelihood:                -1337.8
# No. Observations:                 728   AIC:                             2686.
# Df Residuals:                     723   BIC:                             2709.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0926      0.059      1.557      0.119      -0.024       0.209
# Mkt-RF         1.0099      0.018     54.805      0.000       0.974       1.046
# SMB            0.4928      0.036     13.728      0.000       0.422       0.563
# HML            0.2169      0.031      7.041      0.000       0.157       0.277
# Mom           -0.3254      0.018    -18.159      0.000      -0.361      -0.290
# ==============================================================================
# Omnibus:                       76.617   Durbin-Watson:                   1.878
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              280.631
# Skew:                           0.437   Prob(JB):                     1.15e-61
# Kurtosis:                       5.913   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.920
# Method:                 Least Squares   F-statistic:                     1465.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:44   Log-Likelihood:                -1307.0
# No. Observations:                 728   AIC:                             2624.
# Df Residuals:                     723   BIC:                             2647.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0919      0.057      1.623      0.105      -0.019       0.203
# Mkt-RF         0.9538      0.015     61.928      0.000       0.924       0.984
# SMB            0.4767      0.032     14.932      0.000       0.414       0.539
# HML            0.2743      0.028      9.968      0.000       0.220       0.328
# Mom           -0.1277      0.022     -5.842      0.000      -0.171      -0.085
# ==============================================================================
# Omnibus:                       30.631   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.262
# Skew:                          -0.095   Prob(JB):                     1.37e-18
# Kurtosis:                       4.636   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     1045.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.06e-298
# Time:                        22:56:44   Log-Likelihood:                -1328.3
# No. Observations:                 728   AIC:                             2667.
# Df Residuals:                     723   BIC:                             2690.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0431      0.060     -0.716      0.474      -0.161       0.075
# Mkt-RF         0.9829      0.019     52.626      0.000       0.946       1.020
# SMB            0.4716      0.040     11.750      0.000       0.393       0.550
# HML            0.2947      0.031      9.605      0.000       0.235       0.355
# Mom            0.0980      0.028      3.542      0.000       0.044       0.152
# ==============================================================================
# Omnibus:                      105.050   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              791.931
# Skew:                          -0.379   Prob(JB):                    1.08e-172
# Kurtosis:                       8.053   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.939
# Model:                            OLS   Adj. R-squared:                  0.938
# Method:                 Least Squares   F-statistic:                     2618.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:44   Log-Likelihood:                -1352.9
# No. Observations:                 728   AIC:                             2716.
# Df Residuals:                     723   BIC:                             2739.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1241      0.059      2.120      0.034       0.009       0.239
# Mkt-RF         1.1275      0.015     73.858      0.000       1.098       1.157
# SMB            0.7451      0.025     29.229      0.000       0.695       0.795
# HML           -0.0473      0.024     -1.953      0.051      -0.095       0.000
# Mom            0.4016      0.019     21.264      0.000       0.365       0.439
# ==============================================================================
# Omnibus:                       39.610   Durbin-Watson:                   1.882
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.662
# Skew:                           0.299   Prob(JB):                     3.39e-20
# Kurtosis:                       4.612   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.894
# Method:                 Least Squares   F-statistic:                     598.3
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.17e-227
# Time:                        22:56:44   Log-Likelihood:                -1689.4
# No. Observations:                 728   AIC:                             3389.
# Df Residuals:                     723   BIC:                             3412.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0116      0.109     -0.107      0.915      -0.225       0.202
# Mkt-RF         1.1886      0.033     36.146      0.000       1.124       1.253
# SMB            0.3625      0.040      8.987      0.000       0.283       0.442
# HML            0.0559      0.052      1.083      0.279      -0.045       0.157
# Mom           -0.8123      0.036    -22.755      0.000      -0.882      -0.742
# ==============================================================================
# Omnibus:                       60.615   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              316.789
# Skew:                          -0.026   Prob(JB):                     1.62e-69
# Kurtosis:                       6.231   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     1300.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        22:56:44   Log-Likelihood:                -1405.3
# No. Observations:                 728   AIC:                             2821.
# Df Residuals:                     723   BIC:                             2843.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1737      0.068      2.554      0.011       0.040       0.307
# Mkt-RF         1.0565      0.019     55.492      0.000       1.019       1.094
# SMB            0.1964      0.034      5.703      0.000       0.129       0.264
# HML            0.2003      0.034      5.898      0.000       0.134       0.267
# Mom           -0.3717      0.025    -14.644      0.000      -0.421      -0.322
# ==============================================================================
# Omnibus:                       36.329   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.317
# Skew:                           0.085   Prob(JB):                     4.08e-25
# Kurtosis:                       4.917   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     1144.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          5.52e-311
# Time:                        22:56:44   Log-Likelihood:                -1343.7
# No. Observations:                 728   AIC:                             2697.
# Df Residuals:                     723   BIC:                             2720.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0968      0.060      1.602      0.109      -0.022       0.215
# Mkt-RF         0.9902      0.018     55.159      0.000       0.955       1.025
# SMB            0.1804      0.037      4.828      0.000       0.107       0.254
# HML            0.2536      0.032      7.983      0.000       0.191       0.316
# Mom           -0.1312      0.021     -6.181      0.000      -0.173      -0.090
# ==============================================================================
# Omnibus:                       66.058   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              284.975
# Skew:                           0.280   Prob(JB):                     1.31e-62
# Kurtosis:                       6.013   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     1252.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.96e-323
# Time:                        22:56:44   Log-Likelihood:                -1353.5
# No. Observations:                 728   AIC:                             2717.
# Df Residuals:                     723   BIC:                             2740.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0614      0.059      1.042      0.298      -0.054       0.177
# Mkt-RF         1.0048      0.017     59.560      0.000       0.972       1.038
# SMB            0.1743      0.044      3.990      0.000       0.089       0.260
# HML            0.2069      0.033      6.329      0.000       0.143       0.271
# Mom            0.0900      0.024      3.816      0.000       0.044       0.136
# ==============================================================================
# Omnibus:                       85.905   Durbin-Watson:                   2.034
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              679.734
# Skew:                          -0.127   Prob(JB):                    2.50e-148
# Kurtosis:                       7.727   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     1210.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.29e-318
# Time:                        22:56:44   Log-Likelihood:                -1429.9
# No. Observations:                 728   AIC:                             2870.
# Df Residuals:                     723   BIC:                             2893.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0342      0.069      0.498      0.618      -0.100       0.169
# Mkt-RF         1.1127      0.019     59.880      0.000       1.076       1.149
# SMB            0.4582      0.028     16.568      0.000       0.404       0.512
# HML           -0.0350      0.030     -1.185      0.236      -0.093       0.023
# Mom            0.4407      0.020     22.436      0.000       0.402       0.479
# ==============================================================================
# Omnibus:                       14.868   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               27.820
# Skew:                           0.006   Prob(JB):                     9.10e-07
# Kurtosis:                       3.958   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.866
# Method:                 Least Squares   F-statistic:                     583.0
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          1.57e-224
# Time:                        22:56:44   Log-Likelihood:                -1722.7
# No. Observations:                 728   AIC:                             3455.
# Df Residuals:                     723   BIC:                             3478.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1193      0.112      1.069      0.285      -0.100       0.338
# Mkt-RF         1.1592      0.031     37.419      0.000       1.098       1.220
# SMB           -0.0805      0.036     -2.208      0.027      -0.152      -0.009
# HML           -0.0214      0.049     -0.435      0.663      -0.118       0.075
# Mom           -0.7907      0.038    -21.039      0.000      -0.864      -0.717
# ==============================================================================
# Omnibus:                       66.721   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              321.181
# Skew:                          -0.229   Prob(JB):                     1.80e-70
# Kurtosis:                       6.221   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.893
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     854.0
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          3.52e-272
# Time:                        22:56:44   Log-Likelihood:                -1390.4
# No. Observations:                 728   AIC:                             2791.
# Df Residuals:                     723   BIC:                             2814.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2686      0.066      4.090      0.000       0.140       0.397
# Mkt-RF         0.9385      0.019     48.535      0.000       0.901       0.976
# SMB           -0.1846      0.025     -7.410      0.000      -0.233      -0.136
# HML            0.1158      0.028      4.097      0.000       0.060       0.171
# Mom           -0.4297      0.024    -18.147      0.000      -0.476      -0.383
# ==============================================================================
# Omnibus:                       45.937   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.394
# Skew:                          -0.078   Prob(JB):                     8.20e-39
# Kurtosis:                       5.400   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     943.2
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          3.77e-285
# Time:                        22:56:44   Log-Likelihood:                -1311.7
# No. Observations:                 728   AIC:                             2633.
# Df Residuals:                     723   BIC:                             2656.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0055      0.060      0.091      0.928      -0.113       0.124
# Mkt-RF         0.9483      0.016     58.788      0.000       0.917       0.980
# SMB           -0.1946      0.028     -7.017      0.000      -0.249      -0.140
# HML            0.1244      0.025      4.906      0.000       0.075       0.174
# Mom           -0.1024      0.027     -3.862      0.000      -0.154      -0.050
# ==============================================================================
# Omnibus:                       62.310   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              336.797
# Skew:                           0.019   Prob(JB):                     7.33e-74
# Kurtosis:                       6.332   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.890
# Model:                            OLS   Adj. R-squared:                  0.889
# Method:                 Least Squares   F-statistic:                     1038.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          8.03e-298
# Time:                        22:56:44   Log-Likelihood:                -1297.7
# No. Observations:                 728   AIC:                             2605.
# Df Residuals:                     723   BIC:                             2628.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0530      0.051     -1.041      0.298      -0.153       0.047
# Mkt-RF         0.9702      0.016     62.521      0.000       0.940       1.001
# SMB           -0.2128      0.029     -7.391      0.000      -0.269      -0.156
# HML            0.1226      0.027      4.555      0.000       0.070       0.175
# Mom            0.1693      0.023      7.523      0.000       0.125       0.213
# ==============================================================================
# Omnibus:                       78.446   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              570.331
# Skew:                          -0.039   Prob(JB):                    1.43e-124
# Kurtosis:                       7.335   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.902
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     1169.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          6.70e-314
# Time:                        22:56:44   Log-Likelihood:                -1382.7
# No. Observations:                 728   AIC:                             2775.
# Df Residuals:                     723   BIC:                             2798.
# Df Model:                           4
# Covariance Type:                  HC0
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0561      0.062     -0.903      0.366      -0.178       0.066
# Mkt-RF         1.0712      0.016     65.110      0.000       1.039       1.103
# SMB           -0.0164      0.024     -0.682      0.495      -0.064       0.031
# HML           -0.0594      0.025     -2.360      0.018      -0.109      -0.010
# Mom            0.4628      0.024     18.905      0.000       0.415       0.511
# ==============================================================================
# Omnibus:                       27.487   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               65.813
# Skew:                           0.126   Prob(JB):                     5.12e-15
# Kurtosis:                       4.451   Cond. No.                         5.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC0)

# %%
for p, i in zip(portfolios, res_all):
    print(p,':', i.tvalues[0])
# Out:
# SMALL LoPRIOR : -3.08050168034971
# ME1 PRIOR2 : 0.9318155359273299
# ME1 PRIOR3 : 2.9752461333711153
# ME1 PRIOR4 : 3.087068964622376
# SMALL HiPRIOR : 3.317504367467227
# ME2 PRIOR1 : -2.65446939630556
# ME2 PRIOR2 : 1.9735928899830328
# ME2 PRIOR3 : 2.150811957795305
# ME2 PRIOR4 : 3.1840721541855066
# ME2 PRIOR5 : 2.2301985507403654
# ME3 PRIOR1 : -0.08258389809527876
# ME3 PRIOR2 : 1.5569740509431365
# ME3 PRIOR3 : 1.6230854421995147
# ME3 PRIOR4 : -0.715555454331096
# ME3 PRIOR5 : 2.1203170684015156
# ME4 PRIOR1 : -0.10678071150458356
# ME4 PRIOR2 : 2.5543515775217225
# ME4 PRIOR3 : 1.6015391290727155
# ME4 PRIOR4 : 1.0417927105021465
# ME4 PRIOR5 : 0.4981555097448184
# BIG LoPRIOR : 1.068691083491345
# ME5 PRIOR2 : 4.090121392833029
# ME5 PRIOR3 : 0.09077778594164534
# ME5 PRIOR4 : -1.041265162505003
# BIG HiPRIOR : -0.903231615405188
# /tmp/ipykernel_111978/1526723268.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(p,':', i.tvalues[0])

# %%
alphas = [i.params[0] for i in res_all]
betas = [i.params[1:] for i in res_all]
mean_excess = [np.mean(data[p] - data['RF']) for p in portfolios]

res_cross = []

res = sm.OLS(mean_excess, sm.add_constant(np.array([betas, alphas]).T)).fit(cov_type='HC0')
res_cross.append(res)
print(res.summary())
# Out:
# /tmp/ipykernel_111978/2737922691.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   alphas = [i.params[0] for i in res_all]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[147], line 7
#       3 mean_excess = [np.mean(data[p] - data['RF']) for p in portfolios]
#       5 res_cross = []
# ----> 7 res = sm.OLS(mean_excess, sm.add_constant(np.array([betas, alphas]).T)).fit(cov_type='HC0')
#       8 res_cross.append(res)
#       9 print(res.summary())
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 25) + inhomogeneous part.

# %% [markdown]
# We see that the

# %% [markdown]
# # 6 Fama-MacBeth

# %%
np.array([betas, alphas]).T
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 np.array([betas, alphas]).T
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (2, 25) + inhomogeneous part.

# %%
# Out:
#   Cell In[162], line 1
#     *betas
#     ^
# SyntaxError: can't use starred expression here
