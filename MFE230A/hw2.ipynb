# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cov=pd.read_csv('CovarianceMatrix.csv',header=None)
expected_excess_return=pd.read_csv('ExpectedExcessReturns.csv',header=None)
market_excess_return=pd.read_csv('MarketExcessReturns.csv',header=None)
monthly_excess_returns=pd.read_csv('MonthlyExcessReturns.csv',header=None)

# %% [markdown]
# #### (a)

# %% [markdown]
# ##### (i)

# %% [markdown]
# $$ min_{\alpha}\ \frac{1}{2}\alpha^{'}\Sigma\alpha$$
# $$ st.\ \mu_{0}=r_{f}+\alpha^{'}(\mu-r_{f}\mathbf{1})$$
# We get,
# $$
# \alpha = \frac{\mu_0 - r_f}{A r_f^2 - 2 r_f B + C r_f^2}\Sigma^{-1} (\mu - r_f \mathbf{1})
# $$
# $$
# \sigma=\frac{1}{2}\alpha^{'}\Sigma\alpha=\frac{\mu_0 - r_f}{A r_f^2 - 2 r_f B + C r_f^2}\sqrt{(\mu-r_{f})^T\Sigma^{-1}(\mu-r_{f})}
# $$
# $$
# Sharpe=\frac{\mu_0-r_f}{\sigma}=\frac{A r_f^2 - 2 r_f B + C r_f^2}{\sqrt{(\mu-r_{f})^T\Sigma^{-1}(\mu-r_{f})}}$$
# We can see the sharpe ratio does not depend on $\mu_0$, and given $\mu_0$, the numerator in sharpe is fixed. When we try to minimize $\sigma$, equivalently we are trying to maximize the sharpe.

# %% [markdown]
# ##### (ii)

# %% [markdown]
# In the slides, the formula is:
# $$ w^*=\frac{\Sigma^{-1}(\mu-r_f \mathbf{1})}{B-Ar_f}$$
# where $$ A=\mathbf{1}^{'}\Sigma^{-1}\mathbf{1},B=\mathbf{1}^{'}\Sigma^{-1}\mu$$
# we take $$\mu_e=\mu-r_f\mathbf{1}$$
# we can see $$w^*=\frac{\Sigma^{-1}\mu_e}{\mathbf{1}^{'}\Sigma^{-1}\mu_e}$$

# %% [markdown]
# #### (b)

# %%
estimate_miu_rf=np.array(monthly_excess_returns.mean()).reshape(-1,1)
estimate_cov=np.cov(monthly_excess_returns.T)
market_excess_return=np.array(market_excess_return).reshape(-1,1)
monthly_excess_returns=np.array(monthly_excess_returns)
stock_num=len(cov)
rf=0.002

# %% [markdown]
# ##### (i)

# %%
def calculate_sharpe_ratio(market_excess_return):
    sharpe_ratio_market = market_excess_return.mean() / market_excess_return.std()
    print('Sharpe ratio of market: ', sharpe_ratio_market)
    return sharpe_ratio_market
calculate_sharpe_ratio(market_excess_return)
# Out:
# Sharpe ratio of market:  0.16966343483176566
# 0.16966343483176566

# %% [markdown]
# #### (ii)

# %%
def avg_portfolio(estimate_miu_rf, estimate_cov):
    ones = np.ones((stock_num,1))
    estimate_portfolio_S1N=(estimate_miu_rf.mean())/(np.sqrt(ones.T@estimate_cov@ones)/stock_num)
    print('Sharpe ratio of 1/N portfolio: ', estimate_portfolio_S1N[0,0])
    return estimate_portfolio_S1N[0,0]
avg_portfolio(estimate_miu_rf,estimate_cov)
# Out:
# Sharpe ratio of 1/N portfolio:  0.1771879126534085
# 0.1771879126534085

# %% [markdown]
# #### (iii)

# %% [markdown]
# In the slides, the optimal sharpe ratio formula is:
# $$ w^*=\frac{\Sigma^{-1}(\mu-r_f \mathbf{1})}{B-Ar_f}$$
# where $$ A=\mathbf{1}^{'}\Sigma^{-1}\mathbf{1},B=\mathbf{1}^{'}\Sigma^{-1}\mu$$

# %%
def sharpe(weight,miu,cov):
    return ((miu.T@weight)/np.sqrt(weight.T@cov@weight))
def optimal(estimate_cov,estimate_miu_rf):
    ones=np.ones((stock_num,1))
    inverse_cov=np.linalg.inv(estimate_cov)
    A=ones.T@inverse_cov@ones
    B=ones.T@inverse_cov@estimate_miu_rf
    C=(estimate_miu_rf+rf).T@inverse_cov@(estimate_miu_rf+rf)
    return ((A*rf**2-2*B*rf+C**rf**2)/np.sqrt(estimate_miu_rf.T@inverse_cov@estimate_miu_rf))[0,0]
optimal(estimate_cov,estimate_miu_rf)
# Out:
# 2.579258345923899

# %% [markdown]
# #### (iv)

# %% [markdown]
# $$ min_w \ w^{T}\Sigma^{-1}w$$
# $$st. \ w^{T}\mathbf{1}=1$$
# we get $$w=\frac{\Sigma^{-1}\mathbf{1}}{\mathbf{1^{T}}\Sigma{-1}\mathbf{1}}$$
# $$ vol_{min}=\frac{1}{\mathbf{1}\Sigma^{-1}\mathbf{1}}

# %%
def min_variance(estimate_miu_rf,estimate_cov):
    ones=np.ones((len(estimate_cov),1))
    inverse_cov=np.linalg.inv(estimate_cov)
    weight = inverse_cov@ones/(ones.T@inverse_cov@ones)
    ans=sharpe(weight,estimate_miu_rf,estimate_cov)
    return ans[0,0]
min_variance(estimate_miu_rf,estimate_cov)
# Out:
# 0.08683707693753023

# %% [markdown]
# #### (v)

# %%
def jsj(estimate_miu_rf,estimate_cov):
    ones=np.ones((stock_num,1))
    t=360
    inverse_cov=np.linalg.inv(estimate_cov)
    mu_0=ones.T@inverse_cov@estimate_miu_rf/(ones.T@inverse_cov@ones)[0,0]
    v=(stock_num+2)/(stock_num+2+t*(estimate_miu_rf-mu_0*ones).T@inverse_cov@(estimate_miu_rf-mu_0*ones))[0,0]
    mu_jsj=(1-v)*estimate_miu_rf+v*mu_0*ones
    sharpe_ratio_jsj=optimal(estimate_cov,mu_jsj)
    print('Sharpe ratio of optimal portfolio: ', sharpe_ratio_jsj)
    return sharpe_ratio_jsj
jsj(estimate_miu_rf,estimate_cov)
# Out:
# Sharpe ratio of optimal portfolio:  4.859532935326952
# 4.859532935326952

# %% [markdown]
# #### (vi)

# %%
def capm(market_excess_return,monthly_excess_returns,estimate_cov):
    def calc_capm_beta(market_excess_return, stock_excess_return):
        beta=[]
        for i in range(stock_excess_return.shape[1]):
            beta.append(np.cov(stock_excess_return[:,i], market_excess_return[:,0])[0,1] / np.var(market_excess_return))
        return beta
    beta=calc_capm_beta(market_excess_return, monthly_excess_returns)
    capm_expected_excess_return =(np.array(beta) * market_excess_return.mean()).reshape(stock_num,1)
    capm_sharpe_ratio=optimal(estimate_cov,capm_expected_excess_return)
    print('Sharpe ratio of CAPM optimal portfolio: ', capm_sharpe_ratio)
    return capm_sharpe_ratio
capm(market_excess_return,monthly_excess_returns,estimate_cov)
# Out:
# Sharpe ratio of CAPM optimal portfolio:  5.852429651591251
# 5.852429651591251

# %% [markdown]
# #### (vii)

# %% [markdown]
# The optimization problem can be written as:
# $$ max_{\alpha} \frac{(\alpha^{T}\mu_e)^2}{\alpha^{T}\Sigma\alpha}$$
# $$st.\ \alpha^{T}\mathbf{1}=1$$
# $$ \alpha\geqslant\mathbf{0}$$

# %%
from scipy.optimize import minimize
def c_mv(estimate_miu_rf,estimate_cov):
    def negative_sharpe_ratio_squared(x, mu_e, Sigma):
        alpha = x.reshape(-1,1)
        portfolio_return = (alpha.T @ mu_e)
        portfolio_volatility = np.sqrt(alpha.T @Sigma @ alpha)
        sharpe_ratio_squared = portfolio_return / portfolio_volatility
        return -sharpe_ratio_squared[0]

    initial_guess = 1 / stock_num * np.ones(stock_num)
    bounds = [(0, 1)]*stock_num 
    constraints = (
        {'type': 'eq', 'fun': lambda x: 1-np.sum(x)},  
    )
    result = minimize(negative_sharpe_ratio_squared, initial_guess, args=(estimate_miu_rf, estimate_cov),
                    method='SLSQP', bounds=bounds, constraints=constraints)
    alpha_optimal = result.x
    print(np.sum(alpha_optimal))
    print('S_c_mv: ', -negative_sharpe_ratio_squared(alpha_optimal, estimate_miu_rf, estimate_cov)[0])
    return -negative_sharpe_ratio_squared(alpha_optimal, estimate_miu_rf, estimate_cov)[0]
c_mv(estimate_miu_rf,estimate_cov)
# Out:
# 1.0000000000000007
# S_c_mv:  0.24049039890645454
# 0.24049039890645454

# %% [markdown]
# #### 3

# %%
N = 50  
T = 360 
q = 0.05 
rf = 0.002 
rm = 0.0008 
def simulate_returns():
    beta_n = np.random.uniform(0.5, 1.5, N)
    alpha_n = np.random.uniform(0.1, 0.3, N)
    idiosyncratic_shock = np.random.normal(0, 1, (T, 1))
    returns = rf + beta_n * rm + alpha_n * idiosyncratic_shock
    cov_matrix = np.diag(alpha_n**2) + q**2 * np.outer(beta_n, beta_n)
    expected_returns = rf + rm * beta_n
    
    return returns, cov_matrix, expected_returns, beta_n

returns, cov_matrix, expected_returns, beta_n = simulate_returns()

# %%
avg_1n=[]
optimal_portfolio=[]
min_variance_portfolio=[]
jsj_portfolio=[]
capm_portfolio=[]
cmv=[]
simulation_num=10000
market_excess_return_simulation=np.array([0.0008]*360).reshape(-1,1)
for _ in range(simulation_num):
    returns, cov_matrix_simulation, expected_returns_simulation, beta_n = simulate_returns()
    expected_excess_return_simulation=(returns.mean(axis=0)-rf).reshape(-1,1)
    stock_excess_return_simulation=returns-rf
    avg_1n.append(avg_portfolio(expected_excess_return_simulation,cov_matrix_simulation))
    optimal_portfolio.append(optimal(cov_matrix_simulation,expected_excess_return_simulation))
    min_variance_portfolio.append(min_variance(expected_excess_return_simulation,cov_matrix_simulation))
    jsj_portfolio.append(jsj(expected_excess_return_simulation,cov_matrix_simulation))
    capm_portfolio.append(capm(market_excess_return_simulation,stock_excess_return_simulation, cov_matrix_simulation))
    # cmv.append(c_mv(expected_excess_return_simulation,cov_matrix_simulation))
# Out:
# Sharpe ratio of 1/N portfolio:  0.21686255915569017
# Sharpe ratio of optimal portfolio:  4.670256641674636
# Sharpe ratio of CAPM optimal portfolio:  1.3627289126907283
# Sharpe ratio of 1/N portfolio:  0.316276912777341
# Sharpe ratio of optimal portfolio:  3.1301021851825888
# Sharpe ratio of CAPM optimal portfolio:  1.6324008977337359
# Sharpe ratio of 1/N portfolio:  0.0726408574164109
# Sharpe ratio of optimal portfolio:  14.120479190038292
# Sharpe ratio of CAPM optimal portfolio:  1.3996268491290604
# Sharpe ratio of 1/N portfolio:  -0.08623603635743006
# Sharpe ratio of optimal portfolio:  12.147370850454351
# Sharpe ratio of CAPM optimal portfolio:  2.2382785628115323
# Sharpe ratio of 1/N portfolio:  -0.13276007811059695
# Sharpe ratio of optimal portfolio:  7.899397999340058
# Sharpe ratio of CAPM optimal portfolio:  2.21530036381246
# Sharpe ratio of 1/N portfolio:  -0.30849265262042047
# Sharpe ratio of optimal portfolio:  3.647058550032053
# Sharpe ratio of CAPM optimal portfolio:  1.6959675164631496
# Sharpe ratio of 1/N portfolio:  -0.020944337993511763
# Sharpe ratio of optimal portfolio:  47.46783515276576
# Sharpe ratio of CAPM optimal portfolio:  1.384896611220503
# Sharpe ratio of 1/N portfolio:  -0.08730700061680306
# Sharpe ratio of optimal portfolio:  11.644866740286085
# Sharpe ratio of CAPM optimal portfolio:  1.8507323640983149
# Sharpe ratio of 1/N portfolio:  0.10716706908882641
# Sharpe ratio of optimal portfolio:  9.570134185994178
# Sharpe ratio of CAPM optimal portfolio:  1.7588583653036323
# Sharpe ratio of 1/N portfolio:  -0.01691208010706032
# Sharpe ratio of optimal portfolio:  57.41846611837582
# Sharpe ratio of CAPM optimal portfolio:  1.267744963525407
# Sharpe ratio of 1/N portfolio:  0.051428963138507255
# Sharpe ratio of optimal portfolio:  20.531983911064774
# Sharpe ratio of CAPM optimal portfolio:  0.8186208502341129
# Sharpe ratio of 1/N portfolio:  -0.0754156028772613
# Sharpe ratio of optimal portfolio:  13.17100476117206
# Sharpe ratio of CAPM optimal portfolio:  1.5048289949616702
# Sharpe ratio of 1/N portfolio:  0.03137865318825533
# Sharpe ratio of optimal portfolio:  33.58533444761822
# Sharpe ratio of CAPM optimal portfolio:  1.8961715141985476
# Sharpe ratio of 1/N portfolio:  -0.16313563538405307
# Sharpe ratio of optimal portfolio:  6.598345495026436
# Sharpe ratio of CAPM optimal portfolio:  1.2285222515737617
# Sharpe ratio of 1/N portfolio:  0.19681507202477863
# Sharpe ratio of optimal portfolio:  5.433962384010469
# Sharpe ratio of CAPM optimal portfolio:  1.6146886148462147
# Sharpe ratio of 1/N portfolio:  -0.05752423695485917
# Sharpe ratio of optimal portfolio:  18.606609570685904
# Sharpe ratio of CAPM optimal portfolio:  1.6222359909170734
# Sharpe ratio of 1/N portfolio:  -0.014457356873349734
# Sharpe ratio of optimal portfolio:  60.44313766448995
# Sharpe ratio of CAPM optimal portfolio:  1.9553009600995614
# Sharpe ratio of 1/N portfolio:  0.1032021557190659
# Sharpe ratio of optimal portfolio:  10.353767618471064
# Sharpe ratio of CAPM optimal portfolio:  2.0548965891242017
# Sharpe ratio of 1/N portfolio:  -0.1438153646863151
# Sharpe ratio of optimal portfolio:  7.324230038015998
# Sharpe ratio of CAPM optimal portfolio:  1.3368313534516445
# Sharpe ratio of 1/N portfolio:  -0.3020658234658834
# Sharpe ratio of optimal portfolio:  3.7186824602086355
# Sharpe ratio of CAPM optimal portfolio:  1.3958131746349154
# Sharpe ratio of 1/N portfolio:  0.05288751195720078
# Sharpe ratio of optimal portfolio:  19.64415012246715
# Sharpe ratio of CAPM optimal portfolio:  1.7331046925191342
# Sharpe ratio of 1/N portfolio:  -0.02152533482876812
# Sharpe ratio of optimal portfolio:  45.522139019774336
# Sharpe ratio of CAPM optimal portfolio:  2.197608817766909
# Sharpe ratio of 1/N portfolio:  0.10678578969944852
# Sharpe ratio of optimal portfolio:  9.888518360625476
# Sharpe ratio of CAPM optimal portfolio:  1.4102498664118412
# Sharpe ratio of 1/N portfolio:  0.0909165256636188
# Sharpe ratio of optimal portfolio:  11.246735468466587
# Sharpe ratio of CAPM optimal portfolio:  1.814790176816377
# Sharpe ratio of 1/N portfolio:  0.024658362229875223
# Sharpe ratio of optimal portfolio:  43.99144362523961
# Sharpe ratio of CAPM optimal portfolio:  1.2055833860460055
# Sharpe ratio of 1/N portfolio:  0.09961848736906008
# Sharpe ratio of optimal portfolio:  10.40951297136452
# Sharpe ratio of CAPM optimal portfolio:  1.0023262838176872
# Sharpe ratio of 1/N portfolio:  -0.048930240424384916
# Sharpe ratio of optimal portfolio:  20.448686967731064
# Sharpe ratio of CAPM optimal portfolio:  1.9437469474664018
# Sharpe ratio of 1/N portfolio:  -0.27232871243359996
# Sharpe ratio of optimal portfolio:  3.8301387484836913
# Sharpe ratio of CAPM optimal portfolio:  1.0744881843350185
# Sharpe ratio of 1/N portfolio:  0.02052095578219174
# Sharpe ratio of optimal portfolio:  53.08741656951242
# Sharpe ratio of CAPM optimal portfolio:  1.8340547148222104
# Sharpe ratio of 1/N portfolio:  -0.30460187219865437
# Sharpe ratio of optimal portfolio:  3.6645104680921774
# Sharpe ratio of CAPM optimal portfolio:  1.6085542683252254
# Sharpe ratio of 1/N portfolio:  0.22767685581704789
# Sharpe ratio of optimal portfolio:  4.412436807548282
# Sharpe ratio of CAPM optimal portfolio:  1.3414882191667385
# Sharpe ratio of 1/N portfolio:  0.09594235103076208
# Sharpe ratio of optimal portfolio:  11.252320973701657
# Sharpe ratio of CAPM optimal portfolio:  2.1019247203150813
# Sharpe ratio of 1/N portfolio:  0.11379704123906333
# Sharpe ratio of optimal portfolio:  9.043542857217616
# Sharpe ratio of CAPM optimal portfolio:  1.8825566261966793
# Sharpe ratio of 1/N portfolio:  0.06436880976901675
# Sharpe ratio of optimal portfolio:  16.632983921050183
# Sharpe ratio of CAPM optimal portfolio:  0.7361186505251156
# Sharpe ratio of 1/N portfolio:  -0.20198665138660027
# Sharpe ratio of optimal portfolio:  5.314995122669614
# Sharpe ratio of CAPM optimal portfolio:  1.8691982325981837
# Sharpe ratio of 1/N portfolio:  0.1360994457689285
# Sharpe ratio of optimal portfolio:  7.621099947387607
# Sharpe ratio of CAPM optimal portfolio:  1.46287717359498
# Sharpe ratio of 1/N portfolio:  0.08911389450392608
# Sharpe ratio of optimal portfolio:  11.626735607461377
# Sharpe ratio of CAPM optimal portfolio:  1.389474386704293
# Sharpe ratio of 1/N portfolio:  -0.006472728424448916
# Sharpe ratio of optimal portfolio:  128.92376837038117
# Sharpe ratio of CAPM optimal portfolio:  1.8771690839146071
# Sharpe ratio of 1/N portfolio:  0.1313796281193457
# Sharpe ratio of optimal portfolio:  7.869448109438267
# Sharpe ratio of CAPM optimal portfolio:  1.8273938171916388
# Sharpe ratio of 1/N portfolio:  -0.21392396800720515
# Sharpe ratio of optimal portfolio:  4.989008860419791
# Sharpe ratio of CAPM optimal portfolio:  1.4751492565621298
# Sharpe ratio of 1/N portfolio:  0.13251382253648908
# Sharpe ratio of optimal portfolio:  8.02944416343598
# Sharpe ratio of CAPM optimal portfolio:  1.7451008077550882
# Sharpe ratio of 1/N portfolio:  0.31468223003690643
# Sharpe ratio of optimal portfolio:  3.322770005739162
# Sharpe ratio of CAPM optimal portfolio:  1.7866236261084647
# Sharpe ratio of 1/N portfolio:  -0.34186212474896266
# Sharpe ratio of optimal portfolio:  2.889243875623403
# Sharpe ratio of CAPM optimal portfolio:  1.5192302824414143
# Sharpe ratio of 1/N portfolio:  0.1490500181948221
# Sharpe ratio of optimal portfolio:  6.907186277088102
# Sharpe ratio of CAPM optimal portfolio:  2.2017297092491237
# Sharpe ratio of 1/N portfolio:  -0.10769295496147849
# Sharpe ratio of optimal portfolio:  9.626792167074637
# Sharpe ratio of CAPM optimal portfolio:  1.1587278318123346
# Sharpe ratio of 1/N portfolio:  -0.33381727967827385
# Sharpe ratio of optimal portfolio:  3.161578741080146
# Sharpe ratio of CAPM optimal portfolio:  2.097524071850554
# Sharpe ratio of 1/N portfolio:  -0.24888711892678111
# Sharpe ratio of optimal portfolio:  4.217863914288356
# Sharpe ratio of CAPM optimal portfolio:  2.0925290006539963
# Sharpe ratio of 1/N portfolio:  0.053526087484255074
# Sharpe ratio of optimal portfolio:  19.857503504112014
# Sharpe ratio of CAPM optimal portfolio:  1.6053377718793542
# Sharpe ratio of 1/N portfolio:  0.20702910110535364
# Sharpe ratio of optimal portfolio:  5.211093319656152
# Sharpe ratio of CAPM optimal portfolio:  1.3123757489997634
# Sharpe ratio of 1/N portfolio:  -0.20038516505165013
# Sharpe ratio of optimal portfolio:  5.140076850148762
# Sharpe ratio of CAPM optimal portfolio:  1.8624882817954433
# Sharpe ratio of 1/N portfolio:  -0.0839450620042439
# Sharpe ratio of optimal portfolio:  12.469330635265088
# Sharpe ratio of CAPM optimal portfolio:  1.552933213130491
# Sharpe ratio of 1/N portfolio:  0.1204937825344572
# Sharpe ratio of optimal portfolio:  8.831834133349359
# Sharpe ratio of CAPM optimal portfolio:  1.3239684963599154
# Sharpe ratio of 1/N portfolio:  0.18749617975198696
# Sharpe ratio of optimal portfolio:  5.215743598748303
# Sharpe ratio of CAPM optimal portfolio:  1.8815835063642976
# Sharpe ratio of 1/N portfolio:  0.10159772072570641
# Sharpe ratio of optimal portfolio:  10.706799196851152
# Sharpe ratio of CAPM optimal portfolio:  1.2372947981651776
# Sharpe ratio of 1/N portfolio:  -0.21297837581621792
# Sharpe ratio of optimal portfolio:  4.990253529103524
# Sharpe ratio of CAPM optimal portfolio:  1.8854269832804853
# Sharpe ratio of 1/N portfolio:  -0.13300758901053905
# Sharpe ratio of optimal portfolio:  7.8796284417123195
# Sharpe ratio of CAPM optimal portfolio:  2.376609710250667
# Sharpe ratio of 1/N portfolio:  0.2983250187812
# Sharpe ratio of optimal portfolio:  3.3964501314324567
# Sharpe ratio of CAPM optimal portfolio:  0.761206238615718
# Sharpe ratio of 1/N portfolio:  0.3037018788575886
# Sharpe ratio of optimal portfolio:  3.322371251315591
# Sharpe ratio of CAPM optimal portfolio:  1.4432186775328455
# Sharpe ratio of 1/N portfolio:  -0.07969080363394823
# Sharpe ratio of optimal portfolio:  12.703439495115578
# Sharpe ratio of CAPM optimal portfolio:  1.7066394706965389
# Sharpe ratio of 1/N portfolio:  0.061980460203924066
# Sharpe ratio of optimal portfolio:  17.13426497527402
# Sharpe ratio of CAPM optimal portfolio:  1.559659119255888
# Sharpe ratio of 1/N portfolio:  0.18102475522866207
# Sharpe ratio of optimal portfolio:  5.59466334651893
# Sharpe ratio of CAPM optimal portfolio:  1.0328527593613634
# Sharpe ratio of 1/N portfolio:  -0.10414921673254729
# Sharpe ratio of optimal portfolio:  9.79468809534719
# Sharpe ratio of CAPM optimal portfolio:  1.8609887612600786
# Sharpe ratio of 1/N portfolio:  0.13886440721639104
# Sharpe ratio of optimal portfolio:  7.6243227062391234
# Sharpe ratio of CAPM optimal portfolio:  1.7914454886431592
# Sharpe ratio of 1/N portfolio:  0.3946358082391432
# Sharpe ratio of optimal portfolio:  2.3987585416260537
# Sharpe ratio of CAPM optimal portfolio:  1.8394141518594775
# Sharpe ratio of 1/N portfolio:  -0.0407165431630172
# Sharpe ratio of optimal portfolio:  26.035850759479416
# Sharpe ratio of CAPM optimal portfolio:  2.301517343979052
# Sharpe ratio of 1/N portfolio:  -0.3860987449451668
# Sharpe ratio of optimal portfolio:  2.8143582718368636
# Sharpe ratio of CAPM optimal portfolio:  1.1964879603087333
# Sharpe ratio of 1/N portfolio:  -0.07843503445542699
# Sharpe ratio of optimal portfolio:  13.741701702685573
# Sharpe ratio of CAPM optimal portfolio:  1.7340696111679417
# Sharpe ratio of 1/N portfolio:  0.17503660784828898
# Sharpe ratio of optimal portfolio:  5.82698552942161
# Sharpe ratio of CAPM optimal portfolio:  1.651724844523214
# Sharpe ratio of 1/N portfolio:  0.06803971593224668
# Sharpe ratio of optimal portfolio:  15.637586446486685
# Sharpe ratio of CAPM optimal portfolio:  1.4036440368992278
# Sharpe ratio of 1/N portfolio:  -0.05889218922083334
# Sharpe ratio of optimal portfolio:  18.327742617582842
# Sharpe ratio of CAPM optimal portfolio:  1.2256975660077887
# Sharpe ratio of 1/N portfolio:  -0.0540468730301666
# Sharpe ratio of optimal portfolio:  16.933209059753473
# Sharpe ratio of CAPM optimal portfolio:  1.0301451194918765
# Sharpe ratio of 1/N portfolio:  -0.19485845690249393
# Sharpe ratio of optimal portfolio:  5.536273253745319
# Sharpe ratio of CAPM optimal portfolio:  1.684550014272543
# Sharpe ratio of 1/N portfolio:  0.026950601932562702
# Sharpe ratio of optimal portfolio:  39.30296681253015
# Sharpe ratio of CAPM optimal portfolio:  1.5796084420078924
# Sharpe ratio of 1/N portfolio:  -0.04078772309489416
# Sharpe ratio of optimal portfolio:  24.74655909790795
# Sharpe ratio of CAPM optimal portfolio:  1.5307187600510057
# Sharpe ratio of 1/N portfolio:  0.17564208094408404
# Sharpe ratio of optimal portfolio:  5.982255100211589
# Sharpe ratio of CAPM optimal portfolio:  1.5177560807705832
# Sharpe ratio of 1/N portfolio:  -0.034302606051170935
# Sharpe ratio of optimal portfolio:  32.960322033091344
# Sharpe ratio of CAPM optimal portfolio:  0.940345731054125
# Sharpe ratio of 1/N portfolio:  0.07105967198428793
# Sharpe ratio of optimal portfolio:  14.492263342325897
# Sharpe ratio of CAPM optimal portfolio:  1.2626214635938855
# Sharpe ratio of 1/N portfolio:  -0.07694622507287145
# Sharpe ratio of optimal portfolio:  13.194250721649652
# Sharpe ratio of CAPM optimal portfolio:  2.075215824627885
# Sharpe ratio of 1/N portfolio:  -0.06679124909704333
# Sharpe ratio of optimal portfolio:  15.910201084962386
# Sharpe ratio of CAPM optimal portfolio:  1.2171657783580554
# Sharpe ratio of 1/N portfolio:  0.23120391345426206
# Sharpe ratio of optimal portfolio:  4.43335330489365
# Sharpe ratio of CAPM optimal portfolio:  2.4634790624907503
# Sharpe ratio of 1/N portfolio:  0.1346816999600872
# Sharpe ratio of optimal portfolio:  7.181946503200509
# Sharpe ratio of CAPM optimal portfolio:  1.6538765352207796
# Sharpe ratio of 1/N portfolio:  -0.03274150210658075
# Sharpe ratio of optimal portfolio:  29.545164898887347
# Sharpe ratio of CAPM optimal portfolio:  1.649325603434291
# Sharpe ratio of 1/N portfolio:  -0.26927464159699765
# Sharpe ratio of optimal portfolio:  3.9930742136727755
# Sharpe ratio of CAPM optimal portfolio:  1.8559339971875313
# Sharpe ratio of 1/N portfolio:  0.40880269302967337
# Sharpe ratio of optimal portfolio:  2.4849324841145366
# Sharpe ratio of CAPM optimal portfolio:  1.52773180544836
# Sharpe ratio of 1/N portfolio:  0.20393000299911587
# Sharpe ratio of optimal portfolio:  4.945391302324643
# Sharpe ratio of CAPM optimal portfolio:  1.4663031473600383
# Sharpe ratio of 1/N portfolio:  0.023458903610894144
# Sharpe ratio of optimal portfolio:  45.50947650232021
# Sharpe ratio of CAPM optimal portfolio:  1.6526597250483812
# Sharpe ratio of 1/N portfolio:  0.10896478830936521
# Sharpe ratio of optimal portfolio:  9.51262733851931
# Sharpe ratio of CAPM optimal portfolio:  1.7408528279041364
# Sharpe ratio of 1/N portfolio:  -0.07838701976719675
# Sharpe ratio of optimal portfolio:  12.729850964342955
# Sharpe ratio of CAPM optimal portfolio:  1.3775929045234148
# Sharpe ratio of 1/N portfolio:  -0.1575245905173169
# Sharpe ratio of optimal portfolio:  6.70122243504183
# Sharpe ratio of CAPM optimal portfolio:  2.636052627394965
# Sharpe ratio of 1/N portfolio:  -0.08356968808397257
# Sharpe ratio of optimal portfolio:  13.741976859449721
# Sharpe ratio of CAPM optimal portfolio:  1.7799266243737395
# Sharpe ratio of 1/N portfolio:  -0.3106376945980158
# Sharpe ratio of optimal portfolio:  3.265980205503244
# Sharpe ratio of CAPM optimal portfolio:  1.511851563473588
# Sharpe ratio of 1/N portfolio:  -0.09115283610669109
# Sharpe ratio of optimal portfolio:  11.010480882449498
# Sharpe ratio of CAPM optimal portfolio:  1.775439883562099
# Sharpe ratio of 1/N portfolio:  -0.09998812626349914
# Sharpe ratio of optimal portfolio:  10.572007005826727
# Sharpe ratio of CAPM optimal portfolio:  1.633620129345919
# Sharpe ratio of 1/N portfolio:  -0.06043859439814091
# Sharpe ratio of optimal portfolio:  15.344940981233421
# Sharpe ratio of CAPM optimal portfolio:  1.2997731834112733
# Sharpe ratio of 1/N portfolio:  -0.21291264490631645
# Sharpe ratio of optimal portfolio:  4.947646420699003
# Sharpe ratio of CAPM optimal portfolio:  1.7931882259713723
# Sharpe ratio of 1/N portfolio:  -0.13205469461350683
# Sharpe ratio of optimal portfolio:  7.905459829999665
# Sharpe ratio of CAPM optimal portfolio:  1.391270317733285
# Sharpe ratio of 1/N portfolio:  -0.15892600093603187
# Sharpe ratio of optimal portfolio:  6.485111470616762
# Sharpe ratio of CAPM optimal portfolio:  1.5923070587129233
# Sharpe ratio of 1/N portfolio:  0.0953058480353537
# Sharpe ratio of optimal portfolio:  10.925673368683386
# Sharpe ratio of CAPM optimal portfolio:  1.9529174250993522
# Sharpe ratio of 1/N portfolio:  -0.3286249138438603
# Sharpe ratio of optimal portfolio:  3.1916118194554848
# Sharpe ratio of CAPM optimal portfolio:  2.4474158894738927
# Sharpe ratio of 1/N portfolio:  0.10630938880531753
# Sharpe ratio of optimal portfolio:  9.452179694562117
# Sharpe ratio of CAPM optimal portfolio:  1.642325833033696
# Sharpe ratio of 1/N portfolio:  -0.1574280921559839
# Sharpe ratio of optimal portfolio:  6.627579665478938
# Sharpe ratio of CAPM optimal portfolio:  1.7332835312987998
# Sharpe ratio of 1/N portfolio:  0.016036718732836273
# Sharpe ratio of optimal portfolio:  69.36120017255695
# Sharpe ratio of CAPM optimal portfolio:  1.2492612987567513
# Sharpe ratio of 1/N portfolio:  -0.03524327884044945
# Sharpe ratio of optimal portfolio:  27.76441962137843
# Sharpe ratio of CAPM optimal portfolio:  1.6608881626517351
# Sharpe ratio of 1/N portfolio:  0.030668727434690318
# Sharpe ratio of optimal portfolio:  34.21021988423046
# Sharpe ratio of CAPM optimal portfolio:  1.6938591186090215
# Sharpe ratio of 1/N portfolio:  0.19122594267378046
# Sharpe ratio of optimal portfolio:  5.59998187080488
# Sharpe ratio of CAPM optimal portfolio:  1.7690373224613785
# Sharpe ratio of 1/N portfolio:  -0.021238826036779696
# Sharpe ratio of optimal portfolio:  49.08799205553507
# Sharpe ratio of CAPM optimal portfolio:  1.7367409333895336
# Sharpe ratio of 1/N portfolio:  -0.040558896939493126
# Sharpe ratio of optimal portfolio:  23.239004654808898
# Sharpe ratio of CAPM optimal portfolio:  1.7925609325676044
# Sharpe ratio of 1/N portfolio:  -0.07006344845046558
# Sharpe ratio of optimal portfolio:  14.427684840895921
# Sharpe ratio of CAPM optimal portfolio:  2.0310343041847134
# Sharpe ratio of 1/N portfolio:  -0.0876709512144028
# Sharpe ratio of optimal portfolio:  11.862294428265692
# Sharpe ratio of CAPM optimal portfolio:  2.0820273689708984
# Sharpe ratio of 1/N portfolio:  0.11682355363161688
# Sharpe ratio of optimal portfolio:  9.206697601776018
# Sharpe ratio of CAPM optimal portfolio:  1.4346434861568393
# Sharpe ratio of 1/N portfolio:  0.18138441059758964
# Sharpe ratio of optimal portfolio:  5.890443747609087
# Sharpe ratio of CAPM optimal portfolio:  1.8463493193750395
# Sharpe ratio of 1/N portfolio:  -0.19771405023823874
# Sharpe ratio of optimal portfolio:  5.10649232828492
# Sharpe ratio of CAPM optimal portfolio:  2.0486557886610326
# Sharpe ratio of 1/N portfolio:  -0.13478884333747446
# Sharpe ratio of optimal portfolio:  7.358243051742005
# Sharpe ratio of CAPM optimal portfolio:  1.651727476368358
# Sharpe ratio of 1/N portfolio:  -0.012924999090751985
# Sharpe ratio of optimal portfolio:  68.07105117902277
# Sharpe ratio of CAPM optimal portfolio:  1.2864079986707986
# Sharpe ratio of 1/N portfolio:  0.20175358150163322
# Sharpe ratio of optimal portfolio:  4.895095205866731
# Sharpe ratio of CAPM optimal portfolio:  1.2869750320731466
# Sharpe ratio of 1/N portfolio:  0.01997828510062497
# Sharpe ratio of optimal portfolio:  54.654472445509676
# Sharpe ratio of CAPM optimal portfolio:  2.3444003425370474
# Sharpe ratio of 1/N portfolio:  -0.12509381879280335
# Sharpe ratio of optimal portfolio:  8.251792473396968
# Sharpe ratio of CAPM optimal portfolio:  1.5469633894625132
# Sharpe ratio of 1/N portfolio:  0.16493806884484954
# Sharpe ratio of optimal portfolio:  6.486135652094334
# Sharpe ratio of CAPM optimal portfolio:  1.9673595337984204
# Sharpe ratio of 1/N portfolio:  -0.04786894172511588
# Sharpe ratio of optimal portfolio:  21.55308172804156
# Sharpe ratio of CAPM optimal portfolio:  1.4300148942300037
# Sharpe ratio of 1/N portfolio:  0.2583760495810374
# Sharpe ratio of optimal portfolio:  4.049481252814327
# Sharpe ratio of CAPM optimal portfolio:  1.198717692894225
# Sharpe ratio of 1/N portfolio:  0.05536844760511179
# Sharpe ratio of optimal portfolio:  18.928237434470944
# Sharpe ratio of CAPM optimal portfolio:  1.7582121287750119
# Sharpe ratio of 1/N portfolio:  0.1062879125423008
# Sharpe ratio of optimal portfolio:  9.80648370837555
# Sharpe ratio of CAPM optimal portfolio:  1.7152236311233338
# Sharpe ratio of 1/N portfolio:  -0.07012864506317744
# Sharpe ratio of optimal portfolio:  14.2107611629178
# Sharpe ratio of CAPM optimal portfolio:  1.064559971775906
# Sharpe ratio of 1/N portfolio:  0.05745042553682383
# Sharpe ratio of optimal portfolio:  17.827416261485265
# Sharpe ratio of CAPM optimal portfolio:  1.8511762916957906
# Sharpe ratio of 1/N portfolio:  -0.04471558473070466
# Sharpe ratio of optimal portfolio:  22.808270517807888
# Sharpe ratio of CAPM optimal portfolio:  1.881821947745197
# Sharpe ratio of 1/N portfolio:  -0.07167272785052343
# Sharpe ratio of optimal portfolio:  13.488753711517514
# Sharpe ratio of CAPM optimal portfolio:  2.312322389682021
# Sharpe ratio of 1/N portfolio:  -0.004724738968415147
# Sharpe ratio of optimal portfolio:  159.23782904659643
# Sharpe ratio of CAPM optimal portfolio:  1.014422617305678
# Sharpe ratio of 1/N portfolio:  -0.1345586725681516
# Sharpe ratio of optimal portfolio:  7.390821880268007
# Sharpe ratio of CAPM optimal portfolio:  1.3380601111013388
# Sharpe ratio of 1/N portfolio:  0.3810038481274108
# Sharpe ratio of optimal portfolio:  2.7020802603297467
# Sharpe ratio of CAPM optimal portfolio:  1.4955233133848438
# Sharpe ratio of 1/N portfolio:  -0.1663265794053589
# Sharpe ratio of optimal portfolio:  6.453493911998321
# Sharpe ratio of CAPM optimal portfolio:  2.0866227380340736
# Sharpe ratio of 1/N portfolio:  0.10449669534708322
# Sharpe ratio of optimal portfolio:  10.55624488143047
# Sharpe ratio of CAPM optimal portfolio:  2.0227718362015485
# Sharpe ratio of 1/N portfolio:  -0.2564749562364617
# Sharpe ratio of optimal portfolio:  4.126238541246977
# Sharpe ratio of CAPM optimal portfolio:  1.401299860978475
# Sharpe ratio of 1/N portfolio:  -0.05377029767543874
# Sharpe ratio of optimal portfolio:  18.076892532428808
# Sharpe ratio of CAPM optimal portfolio:  1.234581398642003
# Sharpe ratio of 1/N portfolio:  0.33782131445389463
# Sharpe ratio of optimal portfolio:  3.0698035109082746
# Sharpe ratio of CAPM optimal portfolio:  2.015571079360544
# Sharpe ratio of 1/N portfolio:  -0.16225530591564377
# Sharpe ratio of optimal portfolio:  6.473893974441385
# Sharpe ratio of CAPM optimal portfolio:  1.8414229806959121
# Sharpe ratio of 1/N portfolio:  0.06179341930675946
# Sharpe ratio of optimal portfolio:  17.35680849582387
# Sharpe ratio of CAPM optimal portfolio:  1.3339550493190675
# Sharpe ratio of 1/N portfolio:  0.01774700058255652
# Sharpe ratio of optimal portfolio:  61.682327112067846
# Sharpe ratio of CAPM optimal portfolio:  1.6688653558385742
# Sharpe ratio of 1/N portfolio:  0.19900798751941623
# Sharpe ratio of optimal portfolio:  5.028244486735082
# Sharpe ratio of CAPM optimal portfolio:  0.9954526455673631
# Sharpe ratio of 1/N portfolio:  -0.03080242920400993
# Sharpe ratio of optimal portfolio:  32.420616696818946
# Sharpe ratio of CAPM optimal portfolio:  1.8790478207194126
# Sharpe ratio of 1/N portfolio:  -0.1824869081077912
# Sharpe ratio of optimal portfolio:  5.68777144945179
# Sharpe ratio of CAPM optimal portfolio:  1.3803182915408616
# Sharpe ratio of 1/N portfolio:  -0.06334186395634701
# Sharpe ratio of optimal portfolio:  16.14460782593769
# Sharpe ratio of CAPM optimal portfolio:  0.9669914892564526
# Sharpe ratio of 1/N portfolio:  -0.06672786414583282
# Sharpe ratio of optimal portfolio:  14.008852586318952
# Sharpe ratio of CAPM optimal portfolio:  1.8886823680947444
# Sharpe ratio of 1/N portfolio:  0.20901979692728587
# Sharpe ratio of optimal portfolio:  4.780598873838031
# Sharpe ratio of CAPM optimal portfolio:  2.000444889855662
# Sharpe ratio of 1/N portfolio:  -0.30168253824933733
# Sharpe ratio of optimal portfolio:  3.7124083391267013
# Sharpe ratio of CAPM optimal portfolio:  0.99670937444828
# Sharpe ratio of 1/N portfolio:  -0.03427749427433961
# Sharpe ratio of optimal portfolio:  31.6019614686887
# Sharpe ratio of CAPM optimal portfolio:  1.0389482974076736
# Sharpe ratio of 1/N portfolio:  0.11835380431159112
# Sharpe ratio of optimal portfolio:  8.642620162175831
# Sharpe ratio of CAPM optimal portfolio:  1.7402620872633863
# Sharpe ratio of 1/N portfolio:  -0.05657898647345988
# Sharpe ratio of optimal portfolio:  17.378888050276572
# Sharpe ratio of CAPM optimal portfolio:  1.6705800682300413
# Sharpe ratio of 1/N portfolio:  0.08884838526343848
# Sharpe ratio of optimal portfolio:  12.664170618901332
# Sharpe ratio of CAPM optimal portfolio:  1.265752972707784
# Sharpe ratio of 1/N portfolio:  -0.15149723308329302
# Sharpe ratio of optimal portfolio:  6.774138833653306
# Sharpe ratio of CAPM optimal portfolio:  1.0105872422744484
# Sharpe ratio of 1/N portfolio:  0.06731316489209044
# Sharpe ratio of optimal portfolio:  15.847471753471172
# Sharpe ratio of CAPM optimal portfolio:  1.3541159138397498
# Sharpe ratio of 1/N portfolio:  0.08456873333090296
# Sharpe ratio of optimal portfolio:  12.540612697881176
# Sharpe ratio of CAPM optimal portfolio:  1.7400554656289604
# Sharpe ratio of 1/N portfolio:  0.10624019097942586
# Sharpe ratio of optimal portfolio:  10.139545470206343
# Sharpe ratio of CAPM optimal portfolio:  1.958405447101822
# Sharpe ratio of 1/N portfolio:  0.18683881977766223
# Sharpe ratio of optimal portfolio:  5.427646718072331
# Sharpe ratio of CAPM optimal portfolio:  1.0923171664382025
# Sharpe ratio of 1/N portfolio:  0.12674535014358862
# Sharpe ratio of optimal portfolio:  8.482731600586636
# Sharpe ratio of CAPM optimal portfolio:  1.7321868301969194
# Sharpe ratio of 1/N portfolio:  0.3357861315400159
# Sharpe ratio of optimal portfolio:  3.004914791487177
# Sharpe ratio of CAPM optimal portfolio:  2.2229249098206174
# Sharpe ratio of 1/N portfolio:  -0.11961239003452133
# Sharpe ratio of optimal portfolio:  8.224117211667823
# Sharpe ratio of CAPM optimal portfolio:  1.6467611100738768
# Sharpe ratio of 1/N portfolio:  -0.13856542431624425
# Sharpe ratio of optimal portfolio:  7.772448093266595
# Sharpe ratio of CAPM optimal portfolio:  1.8476881131352452
# Sharpe ratio of 1/N portfolio:  0.16413282875604762
# Sharpe ratio of optimal portfolio:  6.2323663299006515
# Sharpe ratio of CAPM optimal portfolio:  1.4933330529904953
# Sharpe ratio of 1/N portfolio:  0.08174251555290461
# Sharpe ratio of optimal portfolio:  12.819269444449372
# Sharpe ratio of CAPM optimal portfolio:  1.4070705684094318
# Sharpe ratio of 1/N portfolio:  -0.13326598008706225
# Sharpe ratio of optimal portfolio:  7.443699357540518
# Sharpe ratio of CAPM optimal portfolio:  1.2159921530977498
# Sharpe ratio of 1/N portfolio:  0.05343636176005279
# Sharpe ratio of optimal portfolio:  20.080091085926433
# Sharpe ratio of CAPM optimal portfolio:  1.5213232691803322
# Sharpe ratio of 1/N portfolio:  0.31833244549965795
# Sharpe ratio of optimal portfolio:  3.2832949880957014
# Sharpe ratio of CAPM optimal portfolio:  1.5750979565622423
# Sharpe ratio of 1/N portfolio:  0.01743951065400729
# Sharpe ratio of optimal portfolio:  67.40104914792971
# Sharpe ratio of CAPM optimal portfolio:  1.3620840822684288
# Sharpe ratio of 1/N portfolio:  -0.06205198279545065
# Sharpe ratio of optimal portfolio:  16.932940957743792
# Sharpe ratio of CAPM optimal portfolio:  1.3889768324712863
# Sharpe ratio of 1/N portfolio:  0.012618311952936426
# Sharpe ratio of optimal portfolio:  92.95557441201294
# Sharpe ratio of CAPM optimal portfolio:  1.7500440857183577
# Sharpe ratio of 1/N portfolio:  0.2740247342526792
# Sharpe ratio of optimal portfolio:  3.7538341840656044
# Sharpe ratio of CAPM optimal portfolio:  1.7078158495865323
# Sharpe ratio of 1/N portfolio:  0.06424286313366692
# Sharpe ratio of optimal portfolio:  16.170423458480204
# Sharpe ratio of CAPM optimal portfolio:  1.828601428415538
# Sharpe ratio of 1/N portfolio:  -0.21794778364437642
# Sharpe ratio of optimal portfolio:  4.771828295892125
# Sharpe ratio of CAPM optimal portfolio:  1.6202530690057817
# Sharpe ratio of 1/N portfolio:  0.33770272496447146
# Sharpe ratio of optimal portfolio:  2.999378458338521
# Sharpe ratio of CAPM optimal portfolio:  1.4196796627745478
# Sharpe ratio of 1/N portfolio:  0.006038206588810345
# Sharpe ratio of optimal portfolio:  186.5086029105165
# Sharpe ratio of CAPM optimal portfolio:  1.3280697609645804
# Sharpe ratio of 1/N portfolio:  -0.05526637722096512
# Sharpe ratio of optimal portfolio:  19.20759925340858
# Sharpe ratio of CAPM optimal portfolio:  1.7999992952369
# Sharpe ratio of 1/N portfolio:  -0.010864427725650307
# Sharpe ratio of optimal portfolio:  81.3031388411649
# Sharpe ratio of CAPM optimal portfolio:  1.7421558078841872
# Sharpe ratio of 1/N portfolio:  -0.08773192039233921
# Sharpe ratio of optimal portfolio:  12.887158278626002
# Sharpe ratio of CAPM optimal portfolio:  1.3707960006709212
# Sharpe ratio of 1/N portfolio:  0.16487144841180718
# Sharpe ratio of optimal portfolio:  6.068292050369538
# Sharpe ratio of CAPM optimal portfolio:  1.9505011550720446
# Sharpe ratio of 1/N portfolio:  0.22282761785956823
# Sharpe ratio of optimal portfolio:  4.639463458370388
# Sharpe ratio of CAPM optimal portfolio:  1.7776732417161114
# Sharpe ratio of 1/N portfolio:  -0.18799534311766833
# Sharpe ratio of optimal portfolio:  5.436725131830701
# Sharpe ratio of CAPM optimal portfolio:  1.6850299316614323
# Sharpe ratio of 1/N portfolio:  -0.010845989821586901
# Sharpe ratio of optimal portfolio:  82.9896205497706
# Sharpe ratio of CAPM optimal portfolio:  2.0836617043348404
# Sharpe ratio of 1/N portfolio:  -0.28459065742000766
# Sharpe ratio of optimal portfolio:  3.4309649027795093
# Sharpe ratio of CAPM optimal portfolio:  1.9505268191805554
# Sharpe ratio of 1/N portfolio:  0.12679153986389935
# Sharpe ratio of optimal portfolio:  7.914738545619197
# Sharpe ratio of CAPM optimal portfolio:  1.9908725773263105
# Sharpe ratio of 1/N portfolio:  0.2372203828906635
# Sharpe ratio of optimal portfolio:  4.1172408660370685
# Sharpe ratio of CAPM optimal portfolio:  1.5596707878039617
# Sharpe ratio of 1/N portfolio:  0.03174900658668525
# Sharpe ratio of optimal portfolio:  34.17779703874318
# Sharpe ratio of CAPM optimal portfolio:  1.687308021675898
# Sharpe ratio of 1/N portfolio:  -0.14902071842139467
# Sharpe ratio of optimal portfolio:  7.028073980444113
# Sharpe ratio of CAPM optimal portfolio:  1.4515153378692753
# Sharpe ratio of 1/N portfolio:  0.13258266077593764
# Sharpe ratio of optimal portfolio:  7.454505632846489
# Sharpe ratio of CAPM optimal portfolio:  1.9284506112246478
# Sharpe ratio of 1/N portfolio:  -0.13516169963822347
# Sharpe ratio of optimal portfolio:  7.347699687732071
# Sharpe ratio of CAPM optimal portfolio:  1.2420641757108164
# Sharpe ratio of 1/N portfolio:  0.02618173375592699
# Sharpe ratio of optimal portfolio:  40.9276916972804
# Sharpe ratio of CAPM optimal portfolio:  1.9895434447643139
# Sharpe ratio of 1/N portfolio:  -0.0732169061832414
# Sharpe ratio of optimal portfolio:  14.405378868117067
# Sharpe ratio of CAPM optimal portfolio:  1.4747757527177314
# Sharpe ratio of 1/N portfolio:  0.19189042910346218
# Sharpe ratio of optimal portfolio:  5.571161186092528
# Sharpe ratio of CAPM optimal portfolio:  1.3893638547517355
# Sharpe ratio of 1/N portfolio:  -0.12444014895158537
# Sharpe ratio of optimal portfolio:  7.741911318097644
# Sharpe ratio of CAPM optimal portfolio:  1.6981736861551948
# Sharpe ratio of 1/N portfolio:  0.186193612560275
# Sharpe ratio of optimal portfolio:  5.429507815123423
# Sharpe ratio of CAPM optimal portfolio:  1.4429360592979412
# Sharpe ratio of 1/N portfolio:  -0.017384471242895015
# Sharpe ratio of optimal portfolio:  54.146293671785465
# Sharpe ratio of CAPM optimal portfolio:  0.9756521394756282
# Sharpe ratio of 1/N portfolio:  -0.058252655315570286
# Sharpe ratio of optimal portfolio:  17.192512212222162
# Sharpe ratio of CAPM optimal portfolio:  1.196282309690936
# Sharpe ratio of 1/N portfolio:  0.14924540173349046
# Sharpe ratio of optimal portfolio:  6.982037695304932
# Sharpe ratio of CAPM optimal portfolio:  2.0223346142418537
# Sharpe ratio of 1/N portfolio:  -0.11020611550864097
# Sharpe ratio of optimal portfolio:  9.457636227895382
# Sharpe ratio of CAPM optimal portfolio:  0.9451459432109598
# Sharpe ratio of 1/N portfolio:  0.21054351469028262
# Sharpe ratio of optimal portfolio:  4.618067254687271
# Sharpe ratio of CAPM optimal portfolio:  1.942067223828913
# Sharpe ratio of 1/N portfolio:  0.03706826213481977
# Sharpe ratio of optimal portfolio:  29.302993953847814
# Sharpe ratio of CAPM optimal portfolio:  1.431062161043952
# Sharpe ratio of 1/N portfolio:  -0.11099341545372647
# Sharpe ratio of optimal portfolio:  9.095643166331824
# Sharpe ratio of CAPM optimal portfolio:  1.135438626731135
# Sharpe ratio of 1/N portfolio:  0.019774455238111145
# Sharpe ratio of optimal portfolio:  54.51885721031234
# Sharpe ratio of CAPM optimal portfolio:  1.9803224408446252
# Sharpe ratio of 1/N portfolio:  -0.18253947939732376
# Sharpe ratio of optimal portfolio:  5.838786068968305
# Sharpe ratio of CAPM optimal portfolio:  1.9065998379734836
# Sharpe ratio of 1/N portfolio:  0.12278057323717684
# Sharpe ratio of optimal portfolio:  8.666154738808723
# Sharpe ratio of CAPM optimal portfolio:  1.8164053289996083
# Sharpe ratio of 1/N portfolio:  0.19189249397624591
# Sharpe ratio of optimal portfolio:  5.4197802843857135
# Sharpe ratio of CAPM optimal portfolio:  1.6924959559614325
# Sharpe ratio of 1/N portfolio:  -0.20913187895108318
# Sharpe ratio of optimal portfolio:  4.749978606162983
# Sharpe ratio of CAPM optimal portfolio:  2.0735976596538723
# Sharpe ratio of 1/N portfolio:  -0.05289730516405068
# Sharpe ratio of optimal portfolio:  20.693675320450442
# Sharpe ratio of CAPM optimal portfolio:  1.5382833822258406
# Sharpe ratio of 1/N portfolio:  -0.1914178615561454
# Sharpe ratio of optimal portfolio:  5.555675165457058
# Sharpe ratio of CAPM optimal portfolio:  1.8921938444537343
# Sharpe ratio of 1/N portfolio:  -0.2978687626502853
# Sharpe ratio of optimal portfolio:  3.635874861792648
# Sharpe ratio of CAPM optimal portfolio:  1.1236792683212828
# Sharpe ratio of 1/N portfolio:  0.1003794627197328
# Sharpe ratio of optimal portfolio:  10.1964736207519
# Sharpe ratio of CAPM optimal portfolio:  1.559792005190362
# Sharpe ratio of 1/N portfolio:  0.12961637625086442
# Sharpe ratio of optimal portfolio:  7.762238077281507
# Sharpe ratio of CAPM optimal portfolio:  1.4247327331101323
# Sharpe ratio of 1/N portfolio:  -0.05592341453477181
# Sharpe ratio of optimal portfolio:  17.81779698539073
# Sharpe ratio of CAPM optimal portfolio:  1.8120265039619006
# Sharpe ratio of 1/N portfolio:  0.1406057909501574
# Sharpe ratio of optimal portfolio:  7.311185451937683
# Sharpe ratio of CAPM optimal portfolio:  0.8584735232257676
# Sharpe ratio of 1/N portfolio:  -0.0071808637440144785
# Sharpe ratio of optimal portfolio:  128.14474398469997
# Sharpe ratio of CAPM optimal portfolio:  1.0197860066256808
# Sharpe ratio of 1/N portfolio:  0.18346379904792115
# Sharpe ratio of optimal portfolio:  5.601064795931853
# Sharpe ratio of CAPM optimal portfolio:  1.6434999431737727
# Sharpe ratio of 1/N portfolio:  0.05978163141209809
# Sharpe ratio of optimal portfolio:  18.232557834028015
# Sharpe ratio of CAPM optimal portfolio:  1.6994353365152233
# Sharpe ratio of 1/N portfolio:  -0.12364110102685366
# Sharpe ratio of optimal portfolio:  8.355366984993124
# Sharpe ratio of CAPM optimal portfolio:  1.8477282588605959
# Sharpe ratio of 1/N portfolio:  -0.35928872732699363
# Sharpe ratio of optimal portfolio:  2.8459207714672257
# Sharpe ratio of CAPM optimal portfolio:  1.7850102824326581
# Sharpe ratio of 1/N portfolio:  0.44769675827789546
# Sharpe ratio of optimal portfolio:  2.2114982046383407
# Sharpe ratio of CAPM optimal portfolio:  1.9484605882861878
# Sharpe ratio of 1/N portfolio:  0.11621859455727557
# Sharpe ratio of optimal portfolio:  9.007736620363826
# Sharpe ratio of CAPM optimal portfolio:  1.603357218024106
# Sharpe ratio of 1/N portfolio:  -0.2263632544731237
# Sharpe ratio of optimal portfolio:  4.4482541395222395
# Sharpe ratio of CAPM optimal portfolio:  1.1844330516864205
# Sharpe ratio of 1/N portfolio:  -0.05752582788207984
# Sharpe ratio of optimal portfolio:  16.255071572107823
# Sharpe ratio of CAPM optimal portfolio:  1.6844719054219315
# Sharpe ratio of 1/N portfolio:  0.12582344335416942
# Sharpe ratio of optimal portfolio:  8.877478979887137
# Sharpe ratio of CAPM optimal portfolio:  1.2503569715931397
# Sharpe ratio of 1/N portfolio:  0.24090681847371231
# Sharpe ratio of optimal portfolio:  4.369155141092146
# Sharpe ratio of CAPM optimal portfolio:  2.50472512338354
# Sharpe ratio of 1/N portfolio:  -0.026020521510893457
# Sharpe ratio of optimal portfolio:  36.726601078992054
# Sharpe ratio of CAPM optimal portfolio:  1.771978560586304
# Sharpe ratio of 1/N portfolio:  -0.1978051236476512
# Sharpe ratio of optimal portfolio:  5.107374208966244
# Sharpe ratio of CAPM optimal portfolio:  1.969285266873782
# Sharpe ratio of 1/N portfolio:  0.0017814305200773803
# Sharpe ratio of optimal portfolio:  797.5887576769218
# Sharpe ratio of CAPM optimal portfolio:  1.5944137135686505
# Sharpe ratio of 1/N portfolio:  -0.0014766018059535326
# Sharpe ratio of optimal portfolio:  303.5743277801178
# Sharpe ratio of CAPM optimal portfolio:  1.6178222849484194
# Sharpe ratio of 1/N portfolio:  -0.01852208076142772
# Sharpe ratio of optimal portfolio:  59.08808850353375
# Sharpe ratio of CAPM optimal portfolio:  1.679415793123181
# Sharpe ratio of 1/N portfolio:  -0.05201861332233616
# Sharpe ratio of optimal portfolio:  19.3319243009057
# Sharpe ratio of CAPM optimal portfolio:  1.8192633132308793
# Sharpe ratio of 1/N portfolio:  -0.11325807286974487
# Sharpe ratio of optimal portfolio:  8.91798913221505
# Sharpe ratio of CAPM optimal portfolio:  1.4823983631527673
# Sharpe ratio of 1/N portfolio:  -0.0026914852588753877
# Sharpe ratio of optimal portfolio:  285.7266071790895
# Sharpe ratio of CAPM optimal portfolio:  2.295872248116592
# Sharpe ratio of 1/N portfolio:  0.27547132144251313
# Sharpe ratio of optimal portfolio:  3.587409243191911
# Sharpe ratio of CAPM optimal portfolio:  1.6595453370616493
# Sharpe ratio of 1/N portfolio:  0.06577464000059419
# Sharpe ratio of optimal portfolio:  16.117614979344502
# Sharpe ratio of CAPM optimal portfolio:  1.0828784635828945
# Sharpe ratio of 1/N portfolio:  -0.10527164879186514
# Sharpe ratio of optimal portfolio:  9.891050588869899
# Sharpe ratio of CAPM optimal portfolio:  1.4681421073418837
# Sharpe ratio of 1/N portfolio:  0.18311164727727033
# Sharpe ratio of optimal portfolio:  5.911993185458049
# Sharpe ratio of CAPM optimal portfolio:  0.8869329562794858
# Sharpe ratio of 1/N portfolio:  0.13473123159062286
# Sharpe ratio of optimal portfolio:  7.718439975220574
# Sharpe ratio of CAPM optimal portfolio:  1.2837511920519025
# Sharpe ratio of 1/N portfolio:  -0.3266218620055067
# Sharpe ratio of optimal portfolio:  3.345897862857108
# Sharpe ratio of CAPM optimal portfolio:  1.7181687779671246
# Sharpe ratio of 1/N portfolio:  -0.0626173879511047
# Sharpe ratio of optimal portfolio:  17.33671486619777
# Sharpe ratio of CAPM optimal portfolio:  1.5242352554287517
# Sharpe ratio of 1/N portfolio:  -0.430823566492173
# Sharpe ratio of optimal portfolio:  2.363140015087035
# Sharpe ratio of CAPM optimal portfolio:  1.5804118267125589
# Sharpe ratio of 1/N portfolio:  0.052946332263327664
# Sharpe ratio of optimal portfolio:  20.520998900617244
# Sharpe ratio of CAPM optimal portfolio:  1.386884059105146
# Sharpe ratio of 1/N portfolio:  0.3200698640106406
# Sharpe ratio of optimal portfolio:  3.0838388587424426
# Sharpe ratio of CAPM optimal portfolio:  1.671757855819654
# Sharpe ratio of 1/N portfolio:  0.013441713589055031
# Sharpe ratio of optimal portfolio:  86.39868755194446
# Sharpe ratio of CAPM optimal portfolio:  1.623932301236528
# Sharpe ratio of 1/N portfolio:  -0.036267747908134904
# Sharpe ratio of optimal portfolio:  26.251494845884146
# Sharpe ratio of CAPM optimal portfolio:  1.0213969314248854
# Sharpe ratio of 1/N portfolio:  0.1759818175962751
# Sharpe ratio of optimal portfolio:  5.853807767221132
# Sharpe ratio of CAPM optimal portfolio:  1.5753481997394472
# Sharpe ratio of 1/N portfolio:  0.01611656647289277
# Sharpe ratio of optimal portfolio:  71.98779660005212
# Sharpe ratio of CAPM optimal portfolio:  1.3181867330708383
# Sharpe ratio of 1/N portfolio:  0.19644200878844606
# Sharpe ratio of optimal portfolio:  5.198884735731441
# Sharpe ratio of CAPM optimal portfolio:  1.2859098606993378
# Sharpe ratio of 1/N portfolio:  0.12453894874734078
# Sharpe ratio of optimal portfolio:  8.651151903526276
# Sharpe ratio of CAPM optimal portfolio:  1.8368536277318437
# Sharpe ratio of 1/N portfolio:  -0.37958770142416043
# Sharpe ratio of optimal portfolio:  2.7419460282751653
# Sharpe ratio of CAPM optimal portfolio:  1.6972355184253611
# Sharpe ratio of 1/N portfolio:  0.20045355923670416
# Sharpe ratio of optimal portfolio:  5.032805904983971
# Sharpe ratio of CAPM optimal portfolio:  1.8492256636587567
# Sharpe ratio of 1/N portfolio:  0.25460309943393417
# Sharpe ratio of optimal portfolio:  4.16100361461034
# Sharpe ratio of CAPM optimal portfolio:  2.078337789536582
# Sharpe ratio of 1/N portfolio:  -0.05304633918589355
# Sharpe ratio of optimal portfolio:  19.655162089053587
# Sharpe ratio of CAPM optimal portfolio:  1.6416414656848295
# Sharpe ratio of 1/N portfolio:  -0.2192299915606065
# Sharpe ratio of optimal portfolio:  5.05580910978645
# Sharpe ratio of CAPM optimal portfolio:  1.89939351210926
# Sharpe ratio of 1/N portfolio:  -0.22977217596110172
# Sharpe ratio of optimal portfolio:  4.459405630987526
# Sharpe ratio of CAPM optimal portfolio:  1.7300231105686263
# Sharpe ratio of 1/N portfolio:  0.0959465573101739
# Sharpe ratio of optimal portfolio:  10.824219641275882
# Sharpe ratio of CAPM optimal portfolio:  1.7494526689543681
# Sharpe ratio of 1/N portfolio:  0.29482048943793504
# Sharpe ratio of optimal portfolio:  3.3347817118789154
# Sharpe ratio of CAPM optimal portfolio:  1.8589687022058556
# Sharpe ratio of 1/N portfolio:  -0.07640582050918635
# Sharpe ratio of optimal portfolio:  13.8158207207907
# Sharpe ratio of CAPM optimal portfolio:  1.0968600493888954
# Sharpe ratio of 1/N portfolio:  -0.1255496891969224
# Sharpe ratio of optimal portfolio:  8.64944488170843
# Sharpe ratio of CAPM optimal portfolio:  1.2759337451100317
# Sharpe ratio of 1/N portfolio:  0.0978001263677667
# Sharpe ratio of optimal portfolio:  10.174826061069739
# Sharpe ratio of CAPM optimal portfolio:  1.8457503807761246
# Sharpe ratio of 1/N portfolio:  -0.19872757424674875
# Sharpe ratio of optimal portfolio:  5.281410882437172
# Sharpe ratio of CAPM optimal portfolio:  1.7059044526445557
# Sharpe ratio of 1/N portfolio:  0.050080204837794504
# Sharpe ratio of optimal portfolio:  22.163263701800656
# Sharpe ratio of CAPM optimal portfolio:  0.9894024489252544
# Sharpe ratio of 1/N portfolio:  0.12808436292536812
# Sharpe ratio of optimal portfolio:  8.05272690663857
# Sharpe ratio of CAPM optimal portfolio:  1.6010876573821013
# Sharpe ratio of 1/N portfolio:  0.04335101338905057
# Sharpe ratio of optimal portfolio:  24.692478963981017
# Sharpe ratio of CAPM optimal portfolio:  2.014593987649396
# Sharpe ratio of 1/N portfolio:  0.16029503730277792
# Sharpe ratio of optimal portfolio:  6.5564950316004555
# Sharpe ratio of CAPM optimal portfolio:  2.000622369864471
# Sharpe ratio of 1/N portfolio:  -0.03514383801772977
# Sharpe ratio of optimal portfolio:  26.762458092332366
# Sharpe ratio of CAPM optimal portfolio:  1.5331054654182061
# Sharpe ratio of 1/N portfolio:  0.20283428946297835
# Sharpe ratio of optimal portfolio:  5.054708271701721
# Sharpe ratio of CAPM optimal portfolio:  1.8121628074560558
# Sharpe ratio of 1/N portfolio:  -0.14297650898212627
# Sharpe ratio of optimal portfolio:  7.6401870667294975
# Sharpe ratio of CAPM optimal portfolio:  0.9978333933146268
# Sharpe ratio of 1/N portfolio:  -0.010490153959714877
# Sharpe ratio of optimal portfolio:  85.47740177730516
# Sharpe ratio of CAPM optimal portfolio:  1.5676032056515257
# Sharpe ratio of 1/N portfolio:  0.28760885010193377
# Sharpe ratio of optimal portfolio:  3.6808670394578105
# Sharpe ratio of CAPM optimal portfolio:  1.48986209469565
# Sharpe ratio of 1/N portfolio:  -0.21076934317023802
# Sharpe ratio of optimal portfolio:  4.941997909856394
# Sharpe ratio of CAPM optimal portfolio:  1.2698474959549182
# Sharpe ratio of 1/N portfolio:  0.08269362340558033
# Sharpe ratio of optimal portfolio:  12.64002595141763
# Sharpe ratio of CAPM optimal portfolio:  1.779152686052604
# Sharpe ratio of 1/N portfolio:  -0.18080107209896146
# Sharpe ratio of optimal portfolio:  5.768696145081318
# Sharpe ratio of CAPM optimal portfolio:  2.4066540966039667
# Sharpe ratio of 1/N portfolio:  0.015441464051868926
# Sharpe ratio of optimal portfolio:  71.77404157867939
# Sharpe ratio of CAPM optimal portfolio:  1.261648083288018
# Sharpe ratio of 1/N portfolio:  -0.010433828173154566
# Sharpe ratio of optimal portfolio:  79.84605554924816
# Sharpe ratio of CAPM optimal portfolio:  1.545458757399123
# Sharpe ratio of 1/N portfolio:  -0.16988241825775624
# Sharpe ratio of optimal portfolio:  5.736767394782325
# Sharpe ratio of CAPM optimal portfolio:  1.6484538754987237
# Sharpe ratio of 1/N portfolio:  0.021977355224270606
# Sharpe ratio of optimal portfolio:  51.09120024370729
# Sharpe ratio of CAPM optimal portfolio:  1.763298118792337
# Sharpe ratio of 1/N portfolio:  -0.21878364726087346
# Sharpe ratio of optimal portfolio:  5.240641124170303
# Sharpe ratio of CAPM optimal portfolio:  1.6400367516348784
# Sharpe ratio of 1/N portfolio:  0.13822821710027053
# Sharpe ratio of optimal portfolio:  7.489321452220878
# Sharpe ratio of CAPM optimal portfolio:  2.0354307727673198
# Sharpe ratio of 1/N portfolio:  0.140953212586629
# Sharpe ratio of optimal portfolio:  7.1294500776258065
# Sharpe ratio of CAPM optimal portfolio:  2.3165770936802095
# Sharpe ratio of 1/N portfolio:  -0.299073917080853
# Sharpe ratio of optimal portfolio:  3.3336239631443987
# Sharpe ratio of CAPM optimal portfolio:  1.9896810408365304
# Sharpe ratio of 1/N portfolio:  0.06377382965736506
# Sharpe ratio of optimal portfolio:  16.717276160380194
# Sharpe ratio of CAPM optimal portfolio:  1.4801938522764708
# Sharpe ratio of 1/N portfolio:  -0.0885032348023966
# Sharpe ratio of optimal portfolio:  11.43512809671632
# Sharpe ratio of CAPM optimal portfolio:  1.8191204870388813
# Sharpe ratio of 1/N portfolio:  -0.016234093811873754
# Sharpe ratio of optimal portfolio:  53.972102739323624
# Sharpe ratio of CAPM optimal portfolio:  1.9887857779101588
# Sharpe ratio of 1/N portfolio:  -0.17928791088355878
# Sharpe ratio of optimal portfolio:  5.785461516984909
# Sharpe ratio of CAPM optimal portfolio:  2.3623205005568715
# Sharpe ratio of 1/N portfolio:  -0.3123139846212725
# Sharpe ratio of optimal portfolio:  3.227441779381077
# Sharpe ratio of CAPM optimal portfolio:  1.7235882577235242
# Sharpe ratio of 1/N portfolio:  0.10130156570294906
# Sharpe ratio of optimal portfolio:  10.313486916806177
# Sharpe ratio of CAPM optimal portfolio:  0.9166138742539935
# Sharpe ratio of 1/N portfolio:  0.035919668957675795
# Sharpe ratio of optimal portfolio:  30.297738076225738
# Sharpe ratio of CAPM optimal portfolio:  1.8851590958414202
# Sharpe ratio of 1/N portfolio:  -0.09854313559807153
# Sharpe ratio of optimal portfolio:  10.986059721982594
# Sharpe ratio of CAPM optimal portfolio:  1.1158789637058548
# Sharpe ratio of 1/N portfolio:  -0.10383565330326316
# Sharpe ratio of optimal portfolio:  9.84484228230304
# Sharpe ratio of CAPM optimal portfolio:  1.8319777915931683
# Sharpe ratio of 1/N portfolio:  0.018147969087983582
# Sharpe ratio of optimal portfolio:  64.82821035576684
# Sharpe ratio of CAPM optimal portfolio:  0.9035638462610232
# Sharpe ratio of 1/N portfolio:  0.23491884879028802
# Sharpe ratio of optimal portfolio:  4.376839184611305
# Sharpe ratio of CAPM optimal portfolio:  2.1743039655723004
# Sharpe ratio of 1/N portfolio:  0.12479300214724642
# Sharpe ratio of optimal portfolio:  8.52109423373994
# Sharpe ratio of CAPM optimal portfolio:  1.726954359335989
# Sharpe ratio of 1/N portfolio:  0.15065030847598304
# Sharpe ratio of optimal portfolio:  7.0055011998907135
# Sharpe ratio of CAPM optimal portfolio:  1.8792158416621345
# Sharpe ratio of 1/N portfolio:  0.26036361203698105
# ...
# Sharpe ratio of 1/N portfolio:  0.08221993936843473
# Sharpe ratio of optimal portfolio:  13.233254592459168
# Sharpe ratio of CAPM optimal portfolio:  1.7866229241142046
# Sharpe ratio of 1/N portfolio:  -0.2072842631336659
# Sharpe ratio of optimal portfolio:  4.863315300673527
# Sharpe ratio of CAPM optimal portfolio:  1.696826185056318
# Sharpe ratio of 1/N portfolio:  0.0596888083127041
# Sharpe ratio of optimal portfolio:  16.766217002708792
# Sharpe ratio of CAPM optimal portfolio:  1.3316649643490017
# Sharpe ratio of 1/N portfolio:  -0.0032531631203945865
# Sharpe ratio of optimal portfolio:  229.36468697223307
# Sharpe ratio of CAPM optimal portfolio:  1.990075990404893
# Sharpe ratio of 1/N portfolio:  -0.12661778316296304
# Sharpe ratio of optimal portfolio:  7.827873480145912
# Sharpe ratio of CAPM optimal portfolio:  1.468053259999541
# Sharpe ratio of 1/N portfolio:  -0.2119750429209621
# Sharpe ratio of optimal portfolio:  4.788496973509781
# Sharpe ratio of CAPM optimal portfolio:  2.207848414368873
# Sharpe ratio of 1/N portfolio:  -0.1586581814555506
# Sharpe ratio of optimal portfolio:  6.988825518733701
# Sharpe ratio of CAPM optimal portfolio:  0.7789943661512377
# Sharpe ratio of 1/N portfolio:  0.04380088029667798
# Sharpe ratio of optimal portfolio:  24.21907071100902
# Sharpe ratio of CAPM optimal portfolio:  2.1504192706531824
# Sharpe ratio of 1/N portfolio:  0.030651545609402055
# Sharpe ratio of optimal portfolio:  35.59100738273029
# Sharpe ratio of CAPM optimal portfolio:  1.2823989149683832
# Sharpe ratio of 1/N portfolio:  -0.24975554184434992
# Sharpe ratio of optimal portfolio:  4.436885597038751
# Sharpe ratio of CAPM optimal portfolio:  1.1062369819728044
# Sharpe ratio of 1/N portfolio:  0.19400333041530154
# Sharpe ratio of optimal portfolio:  5.253811402696636
# Sharpe ratio of CAPM optimal portfolio:  1.618348189311403
# Sharpe ratio of 1/N portfolio:  0.26272768372746624
# Sharpe ratio of optimal portfolio:  3.9973700091251567
# Sharpe ratio of CAPM optimal portfolio:  1.3126738307131145
# Sharpe ratio of 1/N portfolio:  0.36260620620219475
# Sharpe ratio of optimal portfolio:  2.8462459551954797
# Sharpe ratio of CAPM optimal portfolio:  1.7814888142365835
# Sharpe ratio of 1/N portfolio:  0.03875585273019317
# Sharpe ratio of optimal portfolio:  27.705988124300237
# Sharpe ratio of CAPM optimal portfolio:  1.4856881966317523
# Sharpe ratio of 1/N portfolio:  -0.12325881801225591
# Sharpe ratio of optimal portfolio:  8.377872829953747
# Sharpe ratio of CAPM optimal portfolio:  2.5855453210104082
# Sharpe ratio of 1/N portfolio:  0.01029523312010025
# Sharpe ratio of optimal portfolio:  121.9030670456738
# Sharpe ratio of CAPM optimal portfolio:  1.6985235820064801
# Sharpe ratio of 1/N portfolio:  -0.23745599681155502
# Sharpe ratio of optimal portfolio:  4.332630666177795
# Sharpe ratio of CAPM optimal portfolio:  2.0819764445562527
# Sharpe ratio of 1/N portfolio:  -0.3132535426742343
# Sharpe ratio of optimal portfolio:  3.3009346979826084
# Sharpe ratio of CAPM optimal portfolio:  1.5192980513971825
# Sharpe ratio of 1/N portfolio:  -0.03534446634653568
# Sharpe ratio of optimal portfolio:  30.37813186700591
# Sharpe ratio of CAPM optimal portfolio:  1.438803123535333
# Sharpe ratio of 1/N portfolio:  -0.08617903801938868
# Sharpe ratio of optimal portfolio:  12.359675052015893
# Sharpe ratio of CAPM optimal portfolio:  1.7846511584956692
# Sharpe ratio of 1/N portfolio:  0.01979121445527571
# Sharpe ratio of optimal portfolio:  56.194437518240065
# Sharpe ratio of CAPM optimal portfolio:  1.2622296454337367
# Sharpe ratio of 1/N portfolio:  -0.38806568381668083
# Sharpe ratio of optimal portfolio:  2.835649051702737
# Sharpe ratio of CAPM optimal portfolio:  1.6366461999148252
# Sharpe ratio of 1/N portfolio:  -0.03269284466653126
# Sharpe ratio of optimal portfolio:  33.07860853352352
# Sharpe ratio of CAPM optimal portfolio:  1.8455677048826264
# Sharpe ratio of 1/N portfolio:  -0.05738320067665402
# Sharpe ratio of optimal portfolio:  18.02145348400031
# Sharpe ratio of CAPM optimal portfolio:  1.3200195811979438
# Sharpe ratio of 1/N portfolio:  0.20991831337606126
# Sharpe ratio of optimal portfolio:  4.735440460649931
# Sharpe ratio of CAPM optimal portfolio:  2.3868081951274274
# Sharpe ratio of 1/N portfolio:  -0.16789543184828282
# Sharpe ratio of optimal portfolio:  6.262127504804323
# Sharpe ratio of CAPM optimal portfolio:  1.6278157034947147
# Sharpe ratio of 1/N portfolio:  0.14051538200173078
# Sharpe ratio of optimal portfolio:  7.468108725436016
# Sharpe ratio of CAPM optimal portfolio:  1.3596549411320653
# Sharpe ratio of 1/N portfolio:  -0.02817942626061255
# Sharpe ratio of optimal portfolio:  33.003942423613836
# Sharpe ratio of CAPM optimal portfolio:  1.4210194975436512
# Sharpe ratio of 1/N portfolio:  -0.09795879000630942
# Sharpe ratio of optimal portfolio:  11.632509292606466
# Sharpe ratio of CAPM optimal portfolio:  2.1986189386344854
# Sharpe ratio of 1/N portfolio:  -0.3544286922061314
# Sharpe ratio of optimal portfolio:  2.9652236926464517
# Sharpe ratio of CAPM optimal portfolio:  1.4402362887730444
# Sharpe ratio of 1/N portfolio:  -0.1379668610997693
# Sharpe ratio of optimal portfolio:  7.140317600495014
# Sharpe ratio of CAPM optimal portfolio:  1.71368967197467
# Sharpe ratio of 1/N portfolio:  0.27859442419023694
# Sharpe ratio of optimal portfolio:  3.6276255345431028
# Sharpe ratio of CAPM optimal portfolio:  2.409081863595217
# Sharpe ratio of 1/N portfolio:  0.210160585756764
# Sharpe ratio of optimal portfolio:  4.870375128659413
# Sharpe ratio of CAPM optimal portfolio:  1.4239541587425932
# Sharpe ratio of 1/N portfolio:  0.0618390668182208
# Sharpe ratio of optimal portfolio:  17.0158606825358
# Sharpe ratio of CAPM optimal portfolio:  0.6505299958954955
# Sharpe ratio of 1/N portfolio:  -0.17103117590756262
# Sharpe ratio of optimal portfolio:  6.494639928866784
# Sharpe ratio of CAPM optimal portfolio:  1.5430192133887528
# Sharpe ratio of 1/N portfolio:  -0.1941770723030667
# Sharpe ratio of optimal portfolio:  5.512024470823782
# Sharpe ratio of CAPM optimal portfolio:  1.6982821671394894
# Sharpe ratio of 1/N portfolio:  0.006402693853257583
# Sharpe ratio of optimal portfolio:  203.78598772556163
# Sharpe ratio of CAPM optimal portfolio:  1.8077276308233807
# Sharpe ratio of 1/N portfolio:  0.06252565832641682
# Sharpe ratio of optimal portfolio:  16.421055200510153
# Sharpe ratio of CAPM optimal portfolio:  1.9581037303398017
# Sharpe ratio of 1/N portfolio:  0.04419741547517136
# Sharpe ratio of optimal portfolio:  24.50492440566146
# Sharpe ratio of CAPM optimal portfolio:  1.7549505639470853
# Sharpe ratio of 1/N portfolio:  0.02086942139583367
# Sharpe ratio of optimal portfolio:  53.24100448428177
# Sharpe ratio of CAPM optimal portfolio:  1.9028043701472057
# Sharpe ratio of 1/N portfolio:  0.001879472372930945
# Sharpe ratio of optimal portfolio:  8858.556334810133
# Sharpe ratio of CAPM optimal portfolio:  1.4557302546928284
# Sharpe ratio of 1/N portfolio:  0.3592400680747275
# Sharpe ratio of optimal portfolio:  2.777605211866897
# Sharpe ratio of CAPM optimal portfolio:  1.5333055964740332
# Sharpe ratio of 1/N portfolio:  -0.06764338502877687
# Sharpe ratio of optimal portfolio:  15.465748878172546
# Sharpe ratio of CAPM optimal portfolio:  0.9191849597039863
# Sharpe ratio of 1/N portfolio:  -0.024662039803606758
# Sharpe ratio of optimal portfolio:  37.27072652303617
# Sharpe ratio of CAPM optimal portfolio:  1.699492111304883
# Sharpe ratio of 1/N portfolio:  0.06227897375723971
# Sharpe ratio of optimal portfolio:  17.774298319853305
# Sharpe ratio of CAPM optimal portfolio:  1.6620073970808509
# Sharpe ratio of 1/N portfolio:  -0.27893925985299267
# Sharpe ratio of optimal portfolio:  3.6198797934789373
# Sharpe ratio of CAPM optimal portfolio:  1.9925213978378218
# Sharpe ratio of 1/N portfolio:  -0.033855608667992684
# Sharpe ratio of optimal portfolio:  28.552705790682275
# Sharpe ratio of CAPM optimal portfolio:  1.5487253808005126
# Sharpe ratio of 1/N portfolio:  -0.1569115989119442
# Sharpe ratio of optimal portfolio:  6.764232612610483
# Sharpe ratio of CAPM optimal portfolio:  1.7631006394324293
# Sharpe ratio of 1/N portfolio:  0.0038539328059928623
# Sharpe ratio of optimal portfolio:  454.248534984481
# Sharpe ratio of CAPM optimal portfolio:  0.9604066281593832
# Sharpe ratio of 1/N portfolio:  0.10691713945842289
# Sharpe ratio of optimal portfolio:  9.826178714559687
# Sharpe ratio of CAPM optimal portfolio:  1.3306930855071095
# Sharpe ratio of 1/N portfolio:  -0.06449493520759246
# Sharpe ratio of optimal portfolio:  15.904840368305376
# Sharpe ratio of CAPM optimal portfolio:  1.6655907146725935
# Sharpe ratio of 1/N portfolio:  0.03763824320162254
# Sharpe ratio of optimal portfolio:  28.82318685283069
# Sharpe ratio of CAPM optimal portfolio:  0.986361981767018
# Sharpe ratio of 1/N portfolio:  0.19619542639229332
# Sharpe ratio of optimal portfolio:  5.09556923706794
# Sharpe ratio of CAPM optimal portfolio:  0.9555290764032479
# Sharpe ratio of 1/N portfolio:  0.05698086449113284
# Sharpe ratio of optimal portfolio:  17.967852790825347
# Sharpe ratio of CAPM optimal portfolio:  1.2606412807167824
# Sharpe ratio of 1/N portfolio:  0.27362201588059454
# Sharpe ratio of optimal portfolio:  3.5805741088455623
# Sharpe ratio of CAPM optimal portfolio:  1.8165160553303281
# Sharpe ratio of 1/N portfolio:  0.05761834555441642
# Sharpe ratio of optimal portfolio:  18.228978110521744
# Sharpe ratio of CAPM optimal portfolio:  2.19231294173622
# Sharpe ratio of 1/N portfolio:  0.2677028172065187
# Sharpe ratio of optimal portfolio:  3.9398420656285373
# Sharpe ratio of CAPM optimal portfolio:  2.18319093425269
# Sharpe ratio of 1/N portfolio:  -0.19826964106375994
# Sharpe ratio of optimal portfolio:  5.286693027095504
# Sharpe ratio of CAPM optimal portfolio:  1.4254729150605498
# Sharpe ratio of 1/N portfolio:  0.1670809487724614
# Sharpe ratio of optimal portfolio:  5.92659705503107
# Sharpe ratio of CAPM optimal portfolio:  2.179719828613299
# Sharpe ratio of 1/N portfolio:  0.05952643734537794
# Sharpe ratio of optimal portfolio:  17.720177622979463
# Sharpe ratio of CAPM optimal portfolio:  1.2998977047024178
# Sharpe ratio of 1/N portfolio:  0.05923988717002226
# Sharpe ratio of optimal portfolio:  18.37013377978581
# Sharpe ratio of CAPM optimal portfolio:  2.327848904632326
# Sharpe ratio of 1/N portfolio:  0.018376908615333094
# Sharpe ratio of optimal portfolio:  60.355501361343904
# Sharpe ratio of CAPM optimal portfolio:  2.005882546004916
# Sharpe ratio of 1/N portfolio:  0.21622427045282194
# Sharpe ratio of optimal portfolio:  4.647500841666871
# Sharpe ratio of CAPM optimal portfolio:  1.5004595928120845
# Sharpe ratio of 1/N portfolio:  0.05023295438499604
# Sharpe ratio of optimal portfolio:  21.090308010980753
# Sharpe ratio of CAPM optimal portfolio:  2.3678068510204575
# Sharpe ratio of 1/N portfolio:  0.14764949472942704
# Sharpe ratio of optimal portfolio:  7.231786166384843
# Sharpe ratio of CAPM optimal portfolio:  2.1326440071180173
# Sharpe ratio of 1/N portfolio:  0.12980573333697415
# Sharpe ratio of optimal portfolio:  8.155520245297316
# Sharpe ratio of CAPM optimal portfolio:  1.5327912803830888
# Sharpe ratio of 1/N portfolio:  0.10623115447920536
# Sharpe ratio of optimal portfolio:  9.731576406466665
# Sharpe ratio of CAPM optimal portfolio:  1.6360389818891514
# Sharpe ratio of 1/N portfolio:  -0.18553197312857522
# Sharpe ratio of optimal portfolio:  5.633259200114695
# Sharpe ratio of CAPM optimal portfolio:  1.9231841777782457
# Sharpe ratio of 1/N portfolio:  0.10730019390820561
# Sharpe ratio of optimal portfolio:  9.556386113360709
# Sharpe ratio of CAPM optimal portfolio:  1.7810722367667424
# Sharpe ratio of 1/N portfolio:  -0.15420467201186705
# Sharpe ratio of optimal portfolio:  6.629076881899443
# Sharpe ratio of CAPM optimal portfolio:  1.4801718300811078
# Sharpe ratio of 1/N portfolio:  0.03263254950011779
# Sharpe ratio of optimal portfolio:  33.15214558225562
# Sharpe ratio of CAPM optimal portfolio:  1.9822603723248016
# Sharpe ratio of 1/N portfolio:  0.09622358444307479
# Sharpe ratio of optimal portfolio:  10.696081937159862
# Sharpe ratio of CAPM optimal portfolio:  1.5151264830696547
# Sharpe ratio of 1/N portfolio:  -0.09674240601463337
# Sharpe ratio of optimal portfolio:  10.938179345713726
# Sharpe ratio of CAPM optimal portfolio:  1.541982618888462
# Sharpe ratio of 1/N portfolio:  -0.3365558090912707
# Sharpe ratio of optimal portfolio:  3.3693498462404774
# Sharpe ratio of CAPM optimal portfolio:  1.5667756920042526
# Sharpe ratio of 1/N portfolio:  -0.17013622310932863
# Sharpe ratio of optimal portfolio:  5.5666336529595215
# Sharpe ratio of CAPM optimal portfolio:  1.0578036121087593
# Sharpe ratio of 1/N portfolio:  -0.19420536392224205
# Sharpe ratio of optimal portfolio:  5.363102365412942
# Sharpe ratio of CAPM optimal portfolio:  1.8567357729632261
# Sharpe ratio of 1/N portfolio:  0.03199170759327216
# Sharpe ratio of optimal portfolio:  33.58328219143827
# Sharpe ratio of CAPM optimal portfolio:  1.408788637475415
# Sharpe ratio of 1/N portfolio:  -0.21471749308760144
# Sharpe ratio of optimal portfolio:  4.771812729707901
# Sharpe ratio of CAPM optimal portfolio:  1.8734044223187702
# Sharpe ratio of 1/N portfolio:  0.12600506060861874
# Sharpe ratio of optimal portfolio:  8.44029885046082
# Sharpe ratio of CAPM optimal portfolio:  2.6083412561171087
# Sharpe ratio of 1/N portfolio:  -0.3341140140537198
# Sharpe ratio of optimal portfolio:  3.2590878024994834
# Sharpe ratio of CAPM optimal portfolio:  1.6280143735558816
# Sharpe ratio of 1/N portfolio:  0.13305990295327852
# Sharpe ratio of optimal portfolio:  7.605607241025937
# Sharpe ratio of CAPM optimal portfolio:  1.36427613973916
# Sharpe ratio of 1/N portfolio:  -0.1802146193444715
# Sharpe ratio of optimal portfolio:  6.167707700125014
# Sharpe ratio of CAPM optimal portfolio:  1.9835013690529597
# Sharpe ratio of 1/N portfolio:  -0.5268040105773224
# Sharpe ratio of optimal portfolio:  1.9573065500350868
# Sharpe ratio of CAPM optimal portfolio:  1.509408978098059
# Sharpe ratio of 1/N portfolio:  -0.10357438006564208
# Sharpe ratio of optimal portfolio:  9.808313688640508
# Sharpe ratio of CAPM optimal portfolio:  1.35506095769894
# Sharpe ratio of 1/N portfolio:  -0.06330036612632081
# Sharpe ratio of optimal portfolio:  16.548768387618672
# Sharpe ratio of CAPM optimal portfolio:  1.6045090605040446
# Sharpe ratio of 1/N portfolio:  -0.07612755168675113
# Sharpe ratio of optimal portfolio:  13.97492969822935
# Sharpe ratio of CAPM optimal portfolio:  1.3129641216746744
# Sharpe ratio of 1/N portfolio:  0.3575542273101151
# Sharpe ratio of optimal portfolio:  2.7315082660705245
# Sharpe ratio of CAPM optimal portfolio:  1.218474717167544
# Sharpe ratio of 1/N portfolio:  0.3832409872499642
# Sharpe ratio of optimal portfolio:  2.5761449797136815
# Sharpe ratio of CAPM optimal portfolio:  1.3884311760412416
# Sharpe ratio of 1/N portfolio:  0.06500685088649595
# Sharpe ratio of optimal portfolio:  17.039159177457016
# Sharpe ratio of CAPM optimal portfolio:  1.557120929053019
# Sharpe ratio of 1/N portfolio:  -0.23830673973776978
# Sharpe ratio of optimal portfolio:  4.560050169972707
# Sharpe ratio of CAPM optimal portfolio:  1.5292460296050252
# Sharpe ratio of 1/N portfolio:  -0.00731298625069053
# Sharpe ratio of optimal portfolio:  96.45977911658412
# Sharpe ratio of CAPM optimal portfolio:  1.6529324119271875
# Sharpe ratio of 1/N portfolio:  0.05118789165912111
# Sharpe ratio of optimal portfolio:  20.832283586278077
# Sharpe ratio of CAPM optimal portfolio:  1.6522886038569249
# Sharpe ratio of 1/N portfolio:  0.2761637989702766
# Sharpe ratio of optimal portfolio:  3.662785573136316
# Sharpe ratio of CAPM optimal portfolio:  1.7700738022269393
# Sharpe ratio of 1/N portfolio:  0.10563105176791177
# Sharpe ratio of optimal portfolio:  9.83910301549367
# Sharpe ratio of CAPM optimal portfolio:  1.4263502231427654
# Sharpe ratio of 1/N portfolio:  -0.35258093725028167
# Sharpe ratio of optimal portfolio:  2.9433528888123566
# Sharpe ratio of CAPM optimal portfolio:  1.4784761737434808
# Sharpe ratio of 1/N portfolio:  0.3224447350004235
# Sharpe ratio of optimal portfolio:  3.100956533819899
# Sharpe ratio of CAPM optimal portfolio:  1.7110687150355774

# %%
print('Average Sharpe ratio of 1/N portfolio: ', np.mean(avg_1n))
print('Average Sharpe ratio of optimal portfolio: ', np.mean(optimal_portfolio))
print('Average Sharpe ratio of minimum variance portfolio: ', np.mean(min_variance_portfolio))
print('Average Sharpe ratio of JSJ portfolio: ', np.mean(jsj_portfolio))
print('Average Sharpe ratio of CAPM portfolio: ', np.mean(capm_portfolio))
# Out:
# Average Sharpe ratio of 1/N portfolio:  0.012931761502950088
# Average Sharpe ratio of optimal portfolio:  14.301140943104087
# Average Sharpe ratio of minimum variance portfolio:  0.01118591390140348
# Average Sharpe ratio of JSJ portfolio:  58.29759369014102
# Average Sharpe ratio of CAPM portfolio:  1.6171285908148383

# %% [markdown]
# ### Q2

# %% [markdown]
# (a)

# %% [markdown]
# $$E_1(u(W_2))=-e^{-\gamma W_1-\gamma(\alpha_1^1\mu_1^1+\alpha_1^2\mu_1^2)+\frac{1}{2}\gamma^2((\alpha_1^1\sigma^2)^2+(\alpha_2^2\sigma^2)^2)}$$

# %% [markdown]
# $$argmax_{\alpha_1^1,\alpha_1^2}-\gamma(\alpha_1^1\mu_1^1+\alpha_1^2\mu_1^2)+\frac{1}{2}\gamma^2((\alpha_1^1\sigma^2)^2+(\alpha_2^2\sigma^2)^2)$$

# %% [markdown]
# $$\alpha_1^1=\frac{\mu_1^1}{\gamma(\sigma^2)^2}, \alpha_1^2=\frac{\mu_1^2}{\gamma(\sigma^2)^2}=0$$

# %% [markdown]
# So maximum expected utility @t=1 is<br>
# $$\max E_1(u(W_2))=-e^{-\gamma W_1-\frac{q-k\tilde{\mu}_0^2}{2(\sigma^2)^2}}$$
# $$E_0(u(W_2))=E_0(-e^{-\gamma W_0-\gamma(\alpha_0^1\tilde{\mu}_0^1+\alpha_0^2\tilde{\mu}_0^2)-\frac{q-k\tilde{\mu}_0^2}{2(\sigma^2)^2}})=E_0(-e^{-\gamma W_0-\gamma(\alpha_0^1\tilde{\mu}_0^1+\alpha_0^2\tilde{\mu}_0^2)-\frac{q-k\tilde{\mu}_0^2}{2(\sigma^2)^2}})=-e^{-\gamma W_0-\frac{q}{2(\sigma^2)^2}}E_0(e^{-\gamma(\alpha_0^1\tilde{\mu}_0^1+\alpha_0^2\tilde{\mu}_0^2)+\frac{k\tilde{\mu}_0^2}{2(\sigma^2)^2}})$$
# $$\alpha_0^1=\frac{\mu_0^1}{\gamma(\sigma^1)^2}=\frac{q}{\gamma(\sigma^1)^2}, \alpha_0^2=\frac{k}{2\gamma(\sigma^2)^2}$$

# %% [markdown]
# (b)

# %% [markdown]
# k is like a scalar for impact on expected return of asset 1 from realized return of asset 2 @t=0. This correlation would impact the investment decisions made per period for asset 1 & 2.<br>
# When k=0, there is zero investment in asset 2 @t=0. And asset 1 return would not be impacted by asset 2 so per period, asset 1 and 2 contribute to maximum expected utility individually.<br>
# When k>0, there would be positive investment in asset 2. When realized return of $\tilde{\mu}_0^2$ goes up, expected return for $\tilde{\mu}_1^1$ goes down, which would reduce asset 1 investment @t=1.

# %% [markdown]
# (c)

# %% [markdown]
# Dollar investment $\alpha_1^2$ is not impacted by $\tilde{\mu}_0$. So when $k\neq 0$, $\alpha_1^2$ is zero anyway. <br>
# Dollar investment $\alpha_1^1$ would be impacted. The expected return for asset 1 @t=1 is $q-k\tilde{\mu}_0^2$ given the realized return. If k>0, when $\tilde{\mu}_0^2$ goes up, it reduces expected return for asset 1 @t=1 which in response, $\alpha_1^1$ is reduced as well. Otherwise, when $\tilde{\mu}_0^2$ goes up, expected return increases then $\alpha_1^1$ is augmented as well.<br>
# Risky-asset weight $\omega_1^1, \omega_1^2$ would be impacted due to $\alpha_1^1$. If k > 0, when $\tilde{\mu}_0^2$ goes up, $\alpha_1^1$ is reduced so $\omega_1^1$ goes down while $\omega_1^2$ increases. If k < 0, when $\tilde{\mu}_0^2$ goes down, $\alpha_1^1$ is increased, $\omega_1^1$ goes up while $\omega_1^2$ decreases.
